# %%
import numpy as np
import pandas as pd

# %%
mtadata=pd.read_csv("turnstile_220625.txt")

# %%
mtadata.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2022  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2022  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2022  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2022  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2022  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/18/2022  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/19/2022  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/19/2022  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/19/2022  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/19/2022  12:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7726949
# 1  REGULAR  7726955
# 2  REGULAR  7726964
# 3  REGULAR  7726999
# 4  REGULAR  7727100
# 5  REGULAR  7727190
# 6  REGULAR  7727254
# ...

# %%
mtadata.tail(10)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 212402  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/23/2022
# 212403  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/23/2022
# 212404  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/23/2022
# 212405  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/23/2022
# 212406  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2022
# 212407  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2022
# 212408  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2022
# 212409  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2022
# 212410  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2022
# 212411  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2022
#
#             TIME     DESC  ENTRIES  \
# 212402  09:00:00  REGULAR        0
# 212403  13:00:00  REGULAR        0
# ...

# %%
mtadata.dtypes
# Out:
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                  int64
# EXITS                                                                    int64
# dtype: object

# %%
mtadata.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
mtadata.shape
# Out:
# (212412, 11)

# %%
mtadata.ndim
# Out:
# 2

# %%
mtadata.describe()
# Out:
#             ENTRIES  \
# count  2.124120e+05
# mean   4.334163e+07
# std    2.254340e+08
# min    0.000000e+00
# 25%    2.482910e+05
# 50%    1.333768e+06
# 75%    5.954074e+06
# max    2.147280e+09
#
#        EXITS
# count                                       2.124120e+05
# mean                                        3.415667e+07
# std                                         1.955789e+08
# min                                         0.000000e+00
# 25%                                         1.349135e+05
# 50%                                         8.897135e+05
# 75%                                         3.916431e+06
# max                                         2.122232e+09

# %%
mtadata.
