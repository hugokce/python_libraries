# %%
#https://www.udemy.com/course/python-data-analysis-with-pandas-library/learn/lecture/22670297?start=15#overview

# %%
import pandas as pd

# %%
char_series = pd.Series(('H','A','R','I'))
char_series
# Out:
# 0    H
# 1    A
# 2    R
# 3    I
# dtype: object

# %%
num_series=pd.Series([2,6,9,12,15,18,21])
print(num_series)
print(type(num_series))
# Out:
# 0     2
# 1     6
# 2     9
# 3    12
# 4    15
# 5    18
# 6    21
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
print(num_series[4])
print(num_series[1:4])
print(num_series[[1,4]])
# Out:
# 15
# 1     6
# 2     9
# 3    12
# dtype: int64
# 1     6
# 4    15
# dtype: int64

# %%
help(pd.date_range(start='01-04-2020', end='19-04-2020'))
# Out:
# Help on DatetimeIndex in module pandas.core.indexes.datetimes object:
#
# class DatetimeIndex(pandas.core.indexes.datetimelike.DatetimeTimedeltaMixin, DatetimeDelegateMixin)
#  |  DatetimeIndex(data=None, freq=None, tz=None, normalize=False, closed=None, ambiguous='raise', dayfirst=False, yearfirst=False, dtype=None, copy=False, name=None)
#  |
#  |  Immutable ndarray of datetime64 data, represented internally as int64, and
#  |  which can be boxed to Timestamp objects that are subclasses of datetime and
#  |  carry metadata such as frequency information.
#  |
#  |  Parameters
#  |  ----------
#  |  data : array-like (1-dimensional), optional
#  |      Optional datetime-like data to construct index with.
#  |  copy : bool
#  |      Make a copy of input ndarray.
#  |  freq : str or pandas offset object, optional
#  |      One of pandas date offset strings or corresponding objects. The string
#  |      'infer' can be passed in order to set the frequency of the index as the
# ...

# %%
date_series=pd.date_range(start='01-04-2020', end='19-04-2020')
print(date_series)
print(type(date_series))
# Out:
# DatetimeIndex(['2020-01-04', '2020-01-05', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-11',
#                '2020-01-12', '2020-01-13',
#                ...
#                '2020-04-10', '2020-04-11', '2020-04-12', '2020-04-13',
#                '2020-04-14', '2020-04-15', '2020-04-16', '2020-04-17',
#                '2020-04-18', '2020-04-19'],
#               dtype='datetime64[ns]', length=107, freq='D')
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
#01-04-2020 1 nisan değil de 4 ocak olarak aldı

# %%
num_series=pd.Series([3,6,9,12,15],index=['a','b','c','d','e'])
num_series
# Out:
# a     3
# b     6
# c     9
# d    12
# e    15
# dtype: int64

# %%
import numpy as np
series1=pd.Series(np.array(range(0,5))+2,index=range(0,5))
series1
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int32

# %%
#Pandas Dataframe

# %%
basket_df=pd.DataFrame({'fruits':['Banana','Guava','Orange','Apple','Kiwi'],
                       'weight':[12,1,24,2,8],
                       'color':['Yellow','Green','Pale yellow','Red','Brown']})
basket_df
# Out:
#    fruits  weight        color
# 0  Banana      12       Yellow
# 1   Guava       1        Green
# 2  Orange      24  Pale yellow
# 3   Apple       2          Red
# 4    Kiwi       8        Brown

# %%
#pd.read_csv()
#pd.read_excel()

# %%
#play with df
basket_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fruits  5 non-null      object
#  1   weight  5 non-null      int64
#  2   color   5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
basket_df.shape
# Out:
# (5, 3)

# %%
basket_df.head()
# Out:
#    fruits  weight        color
# 0  Banana      12       Yellow
# 1   Guava       1        Green
# 2  Orange      24  Pale yellow
# 3   Apple       2          Red
# 4    Kiwi       8        Brown

# %%
basket_df.tail()
# Out:
#    fruits  weight        color
# 0  Banana      12       Yellow
# 1   Guava       1        Green
# 2  Orange      24  Pale yellow
# 3   Apple       2          Red
# 4    Kiwi       8        Brown

# %%
basket_df.describe()
# Out:
#           weight
# count   5.000000
# mean    9.400000
# std     9.316652
# min     1.000000
# 25%     2.000000
# 50%     8.000000
# 75%    12.000000
# max    24.000000

# %%
basket_df.columns
# Out:
# Index(['fruits', 'weight', 'color'], dtype='object')

# %%
basket_df.values
# Out:
# array([['Banana', 12, 'Yellow'],
#        ['Guava', 1, 'Green'],
#        ['Orange', 24, 'Pale yellow'],
#        ['Apple', 2, 'Red'],
#        ['Kiwi', 8, 'Brown']], dtype=object)

# %%
basket_df.set_index('color',inplace=True)
basket_df.head()
# Out:
#              fruits  weight
# color
# Yellow       Banana      12
# Green         Guava       1
# Pale yellow  Orange      24
# Red           Apple       2
# Brown          Kiwi       8

# %%
basket_df[0::2].head()
# Out:
#              fruits  weight
# color
# Yellow       Banana      12
# Pale yellow  Orange      24
# Brown          Kiwi       8

# %%
basket_fruits=basket_df.fruits
basket_fruits.head()
print(type(basket_df.fruits))
# Out:
# <class 'pandas.core.series.Series'>

# %%
basket_fruits=basket_df['fruits']
basket_fruits.head()
print(type(basket_df['fruits']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(basket_df[['fruits']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#subsetting DF

# %%
#basket_df[1]
basket_df.set_index('fruits').head()
# Out:
#         weight
# fruits
# Banana      12
# Guava        1
# Orange      24
# Apple        2
# Kiwi         8

# %%
help(pd.DataFrame.loc)
# Out:
# Help on property:
#
#     Access a group of rows and columns by label(s) or a boolean array.
#
#     ``.loc[]`` is primarily label based, but may also be used with a
#     boolean array.
#
#     Allowed inputs are:
#
#     - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#       interpreted as a *label* of the index, and **never** as an
#       integer position along the index).
#     - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#     - A slice object with labels, e.g. ``'a':'f'``.
#
#       .. warning:: Note that contrary to usual python slices, **both** the
#           start and the stop are included
#
#     - A boolean array of the same length as the axis being sliced,
#       e.g. ``[True, False, True]``.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above)
#
#     See more at :ref:`Selection by Label <indexing.label>`
#
#     Raises
#     ------
# ...

# %%
help(pd.DataFrame.iloc)
# Out:
# Help on property:
#
#     Purely integer-location based indexing for selection by position.
#
#     ``.iloc[]`` is primarily integer position based (from ``0`` to
#     ``length-1`` of the axis), but may also be used with a boolean
#     array.
#
#     Allowed inputs are:
#
#     - An integer, e.g. ``5``.
#     - A list or array of integers, e.g. ``[4, 3, 0]``.
#     - A slice object with ints, e.g. ``1:7``.
#     - A boolean array.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above).
#       This is useful in method chains, when you don't have a reference to the
#       calling object, but would like to base your selection on some value.
#
#     ``.iloc`` will raise ``IndexError`` if a requested indexer is
#     out-of-bounds, except *slice* indexers which allow out-of-bounds
#     indexing (this conforms with python/numpy *slice* semantics).
#
# ...

# %%
basket_df.loc[3,'fruits']
# Out:
# 'Apple'

# %%
basket_df.loc[3]
# Out:
# fruits    Apple
# weight        2
# color       Red
# Name: 3, dtype: object

# %%
basket_df.loc[0:4,:]
# Out:
#    fruits  weight        color
# 0  Banana      12       Yellow
# 1   Guava       1        Green
# 2  Orange      24  Pale yellow
# 3   Apple       2          Red
# 4    Kiwi       8        Brown

# %%
basket_df.reset_index(inplace=True)

# %%
basket_df.loc[1,['weight','color']]
# Out:
# weight        1
# color     Green
# Name: 1, dtype: object

# %%
basket_df.loc[[1,3],'weight':'color']
# Out:
#    weight  color
# 1       1  Green
# 3       2    Red

# %%
basket_df.loc[[True,True,False,True,False]]
# Out:
#    index  fruits  weight   color
# 0      0  Banana      12  Yellow
# 1      1   Guava       1   Green
# 3      3   Apple       2     Red

# %%
basket_df.iloc[:2].head()
# Out:
#    index  fruits  weight   color
# 0      0  Banana      12  Yellow
# 1      1   Guava       1   Green

# %%
basket_df.iloc[1:2,0:3].head()
# Out:
#    index fruits  weight
# 1      1  Guava       1

# %%
basket_df.iloc[[True,True,False,True,False]]
# Out:
#    index  fruits  weight   color
# 0      0  Banana      12  Yellow
# 1      1   Guava       1   Green
# 3      3   Apple       2     Red

# %%
basket_df[basket_df.color=='Yellow']
# Out:
#    index  fruits  weight   color
# 0      0  Banana      12  Yellow

# %%
basket_df.loc[(basket_df.color=='Yellow') & (basket_df.fruits=='Banana'),:]
# Out:
#    index  fruits  weight   color
# 0      0  Banana      12  Yellow

# %%
basket_df.loc[(basket_df.color=='Yellow') | (basket_df.fruits=='Banana'),:]
# Out:
#    index  fruits  weight   color
# 0      0  Banana      12  Yellow

# %%
fruit_segment=['Apple','Banana']
basket_df.loc[basket_df['fruits'].isin(fruit_segment),:]
# Out:
#    index  fruits  weight   color
# 0      0  Banana      12  Yellow
# 3      3   Apple       2     Red

# %%
#pd.merge()
#first_merge_df=pd.merge(market_df,customer_df,
#                        how='inner',on='cust_id')

# %%
#2 df concat etmek için
#pd.concat([df1,df2],axis=0)

# %%
#ayrıca append kullanabiliriz
#df1.append(df2)

# %%
#iki dataframei + ile birleştirine non değerler geliyor

# %%
#df1.add(df2,fill_value=0)  nan değerleri 0 ile doldurmuş olduk

# %%
#df1.sort_values(by=(['kolon1','kolon2']),ascending=False)

# %%
#4 saatlik eğitim csv excel dosyaları paylaşmıyor
#sertifikası var
