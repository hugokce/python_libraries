# %%
"""
https://www.udemy.com/course/learn-data-analysis-using-pandas-and-python/learn/lecture/11211074?start=0#overview
1,5 saat

https://rakeshgopal.teachable.com/

files.zip dosyası var indirildi

Module1i de var

https://pandas.pydata.org/


JSON, XML, SQL SErver, CSV, PipeSeperated, Tab Seperated

googleda tab seperated sample data dedik alttaki linke geçtik

https://datatables.net/extensions/buttons/examples/flash/tsv.html
"""
# Out:
# '\nhttps://www.udemy.com/course/learn-data-analysis-using-pandas-and-python/learn/lecture/11211074?start=0#overview\n1,5 saat\n\nhttps://rakeshgopal.teachable.com/\n\nfiles.zip dosyası var indirildi\n\nModule1i de var\n\nhttps://pandas.pydata.org/\n\n\nJSON, XML, SQL SErver, CSV, PipeSeperated, Tab Seperated\n\ngoogleda tab seperated sample data dedik alttaki linke geçtik\n\nhttps://datatables.net/extensions/buttons/examples/flash/tsv.html\n'

# %%
#read from tsv 

import pandas as pd

# %%
#employee = pd.read_table('D:/Udemy/resources/Tab_separated_values.tsv')
employee = pd.read_table('Tab_separated_values.tsv')
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary
# 0  2008-11-28    $162,700
# 1  2009-10-09  $1,200,000
# 2  2009-01-12     $86,000
# 3  2012-10-13    $132,000
# 4  2011-06-07    $206,850

# %%
#lets try pipe delimited (name|age|salary)
reads = pd.read_table('https://www.nrc.gov/reading-rm/doc-collections/event-status/reactor-status/2009/2009PowerStatus.txt', sep="|")
reads.head()
# Out:
#      ReportDt                Unit  Power
# 0  12/31/2009  Arkansas Nuclear 1    100
# 1  12/31/2009  Arkansas Nuclear 2    100
# 2  12/31/2009     Beaver Valley 1    100
# 3  12/31/2009     Beaver Valley 2    100
# 4  12/31/2009         Braidwood 1    100

# %%
#chapter 4- choose certain column 

cols  = ['Name', 'Position']
#employee = pd.read_table('D:/Udemy/resources/Tab_separated_values.tsv')
employee = pd.read_table('Tab_separated_values.tsv')
employee[cols].head()
# Out:
#              Name                       Position
# 0      Airi Satou                     Accountant
# 1  Angelica Ramos  Chief Executive Officer (CEO)
# 2      Ashton Cox        Junior Technical Author
# 3   Bradley Greer              Software Engineer
# 4  Brenden Wagner              Software Engineer

# %%
employee
# Out:
#                    Name                       Position         Office  Age  \
# 0            Airi Satou                     Accountant          Tokyo   33
# 1        Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 3         Bradley Greer              Software Engineer         London   41
# 4        Brenden Wagner              Software Engineer  San Francisco   28
# 5    Brielle Williamson         Integration Specialist       New York   61
# 6            Bruno Nash              Software Engineer         London   38
# 7          Caesar Vance              Pre-Sales Support       New York   21
# 8          Cara Stevens                Sales Assistant       New York   46
# 9          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 10      Charde Marshall              Regional Director  San Francisco   36
# ...

# %%
#chapter 4- choose certain rows
#employee = pd.read_table('D:/Udemy/resources/Tab_separated_values.tsv', nrows = 4)
employee = pd.read_table('Tab_separated_values.tsv', nrows = 4)
employee
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
#
#    Start date      Salary
# 0  2008-11-28    $162,700
# 1  2009-10-09  $1,200,000
# 2  2009-01-12     $86,000
# 3  2012-10-13    $132,000

# %%
#chapter 4 - display datatypes
#employee = pd.read_table('D:/Udemy/resources/Tab_separated_values.tsv')
employee = pd.read_table('Tab_separated_values.tsv')
employee.dtypes
# Out:
# Name          object
# Position      object
# Office        object
# Age            int64
# Start date    object
# Salary        object
# dtype: object

# %%
#chapter 4 - display integer datatypes
import numpy as np
#employee = pd.read_table('D:/Udemy/resources/Tab_separated_values.tsv')
employee = pd.read_table('Tab_separated_values.tsv')
employee.select_dtypes(include = [np.number]).dtypes
# Out:
# Age    int64
# dtype: object

# %%
#chapter 4 - some inbluit methods for data analysis
employee.describe()
# Out:
#              Age
# count  57.000000
# mean   42.736842
# std    14.877507
# min    19.000000
# 25%    30.000000
# 50%    42.000000
# 75%    56.000000
# max    66.000000

# %%
#chapter 4 - show me the number of rows and columns
employee.shape
# Out:
# (57, 6)

# %%
#chapter 4 - type of object
type(employee)
# Out:
# pandas.core.frame.DataFrame

# %%
#chapter 5 - concatenating 2 columns
employee['Name Salary'] = employee['Name'] + employee['Salary']
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary               Name Salary
# 0  2008-11-28    $162,700        Airi Satou$162,700
# 1  2009-10-09  $1,200,000  Angelica Ramos$1,200,000
# 2  2009-01-12     $86,000         Ashton Cox$86,000
# 3  2012-10-13    $132,000     Bradley Greer$132,000
# 4  2011-06-07    $206,850    Brenden Wagner$206,850

# %%
employee.drop('Office', axis=1, inplace=True)
employee.head()
# Out:
#              Name                       Position  Age  Start date      Salary  \
# 0      Airi Satou                     Accountant   33  2008-11-28    $162,700
# 1  Angelica Ramos  Chief Executive Officer (CEO)   47  2009-10-09  $1,200,000
# 2      Ashton Cox        Junior Technical Author   66  2009-01-12     $86,000
# 3   Bradley Greer              Software Engineer   41  2012-10-13    $132,000
# 4  Brenden Wagner              Software Engineer   28  2011-06-07    $206,850
#
#                 Name Salary
# 0        Airi Satou$162,700
# 1  Angelica Ramos$1,200,000
# 2         Ashton Cox$86,000
# 3     Bradley Greer$132,000
# 4    Brenden Wagner$206,850

# %%
#employee = pd.read_table('D:/Udemy/resources/Tab_separated_values.tsv')
employee = pd.read_table('Tab_separated_values.tsv')
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary
# 0  2008-11-28    $162,700
# 1  2009-10-09  $1,200,000
# 2  2009-01-12     $86,000
# 3  2012-10-13    $132,000
# 4  2011-06-07    $206,850

# %%
#Kolon adlarını değiştirme list üzerinden
cols =['Name', 'Position', 'Ofc', 'Age', 'StartDate', 'Sal']
employee.columns = cols
employee.head()
# Out:
#              Name                       Position            Ofc  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#     StartDate         Sal
# 0  2008-11-28    $162,700
# 1  2009-10-09  $1,200,000
# 2  2009-01-12     $86,000
# 3  2012-10-13    $132,000
# 4  2011-06-07    $206,850

# %%
#employee = pd.read_table('D:/Udemy/resources/Tab_separated_values.tsv')
employee = pd.read_table('Tab_separated_values.tsv')
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary
# 0  2008-11-28    $162,700
# 1  2009-10-09  $1,200,000
# 2  2009-01-12     $86,000
# 3  2012-10-13    $132,000
# 4  2011-06-07    $206,850

# %%
#chapter 5 - Sorting your data (just like your order by clause)
#sort the table by age?
employee.sort_values(by='Age', ascending=True).head()
# Out:
#                    Name               Position         Office  Age  \
# 48  Tatyana Fitzpatrick      Regional Director         London   19
# 45            Shou Itou     Regional Marketing          Tokyo   20
# 7          Caesar Vance      Pre-Sales Support       New York   21
# 32           Lael Greer  Systems Administrator         London   21
# 18         Gavin Cortez            Team Leader  San Francisco   22
#
#     Start date    Salary
# 48  2010-03-17  $385,750
# 45  2011-08-14  $163,000
# 7   2011-12-12  $106,450
# 32  2009-02-27  $103,500
# 18  2008-10-26  $235,500

# %%
#sorting a series
employee['Name'].sort_values().head()
# Out:
# 0        Airi Satou
# 1    Angelica Ramos
# 2        Ashton Cox
# 3     Bradley Greer
# 4    Brenden Wagner
# Name: Name, dtype: object

# %%
#chapter 5 - filtering (just like your where clause)
#select all rows where age < 40

employee[employee.Age < 40].head()
# Out:
#              Name                     Position         Office  Age  \
# 0      Airi Satou                   Accountant          Tokyo   33
# 4  Brenden Wagner            Software Engineer  San Francisco   28
# 6      Bruno Nash            Software Engineer         London   38
# 7    Caesar Vance            Pre-Sales Support       New York   21
# 9    Cedric Kelly  Senior Javascript Developer      Edinburgh   22
#
#    Start date    Salary
# 0  2008-11-28  $162,700
# 4  2011-06-07  $206,850
# 6  2011-05-03  $163,500
# 7  2011-12-12  $106,450
# 9  2012-03-29  $433,060

# %%
#chapter 5 - multi-filtering criteria (just like your where clause)
employee[(employee.Age< 40) & (employee.Name == "Airi Satou")]
# Out:
#          Name    Position Office  Age  Start date    Salary
# 0  Airi Satou  Accountant  Tokyo   33  2008-11-28  $162,700

# %%
cols = ['Name','Position']
employee[employee.Age < 40][cols].head()
# Out:
#              Name                     Position
# 0      Airi Satou                   Accountant
# 4  Brenden Wagner            Software Engineer
# 6      Bruno Nash            Software Engineer
# 7    Caesar Vance            Pre-Sales Support
# 9    Cedric Kelly  Senior Javascript Developer

# %%
#chapter 6 - calculate mean
employee.head()
employee.mean()
# Out:
# C:\Users\Bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Age    42.736842
# dtype: float64

# %%
#chapter 6 - string manipulation
employee.head()
employee.Name.str.upper().head()
# Out:
# 0        AIRI SATOU
# 1    ANGELICA RAMOS
# 2        ASHTON COX
# 3     BRADLEY GREER
# 4    BRENDEN WAGNER
# Name: Name, dtype: object

# %%
employee.Name.str.lower().head()
# Out:
# 0        airi satou
# 1    angelica ramos
# 2        ashton cox
# 3     bradley greer
# 4    brenden wagner
# Name: Name, dtype: object

# %%
employee.head()
employee.Position.str.contains('Software')
employee[employee.Position.str.contains('Software')]
# Out:
#               Name           Position         Office  Age  Start date  \
# 3    Bradley Greer  Software Engineer         London   41  2012-10-13
# 4   Brenden Wagner  Software Engineer  San Francisco   28  2011-06-07
# 6       Bruno Nash  Software Engineer         London   38  2011-05-03
# 46     Sonya Frost  Software Engineer      Edinburgh   23  2008-12-13
# 55   Zenaida Frank  Software Engineer       New York   63  2010-01-04
# 56  Zorita Serrano  Software Engineer  San Francisco   56  2012-06-01
#
#       Salary
# 3   $132,000
# 4   $206,850
# 6   $163,500
# 46  $103,600
# 55  $125,250
# 56  $115,000

# %%
#chapter 6 - replacing strings
employee.head()
employee.Position.str.replace('Engineer', 'Developer').head()
# Out:
# 0                       Accountant
# 1    Chief Executive Officer (CEO)
# 2          Junior Technical Author
# 3               Software Developer
# 4               Software Developer
# Name: Position, dtype: object

# %%
#chapter 6 - aggregations
employee.head()
employee.Age.min()
# Out:
# 19

# %%
employee.Age.max()
# Out:
# 66

# %%
#chapter 6- groupby
employee.groupby('Position').Age.min().head()
# Out:
# Position
# Accountant                       33
# Chief Executive Officer (CEO)    47
# Chief Financial Officer (CFO)    64
# Chief Marketing Officer (CMO)    40
# Chief Operating Officer (COO)    48
# Name: Age, dtype: int64

# %%
employee.groupby('Position').Age.agg(['count','min','max'])
# Out:
#                                count  min  max
# Position
# Accountant                         2   33   63
# Chief Executive Officer (CEO)      1   47   47
# Chief Financial Officer (CFO)      1   64   64
# Chief Marketing Officer (CMO)      1   40   40
# Chief Operating Officer (COO)      1   48   48
# Customer Support                   1   27   27
# Data Coordinator                   1   64   64
# Developer                          4   30   61
# Development Lead                   1   30   30
# Director                           1   65   65
# Financial Controller               1   62   62
# Integration Specialist             3   37   61
# Javascript Developer               2   29   39
# Junior Javascript Developer        1   43   43
# Junior Technical Author            1   66   66
# Marketing Designer                 2   47   66
# Office Manager                     3   30   51
# Personnel Lead                     1   35   35
# Post-Sales support                 1   46   46
# ...

# %%
#chapter 7 - loc (choosing a number of rows or columns) 
#employee = pd.read_table('D:/Udemy/resources/Tab_separated_values.tsv')
employee = pd.read_table('Tab_separated_values.tsv')
#row 0, all columns
employee.loc[0,:]
# Out:
# Name          Airi Satou
# Position      Accountant
# Office             Tokyo
# Age                   33
# Start date    2008-11-28
# Salary          $162,700
# Name: 0, dtype: object

# %%
#row 0-2, all columns
employee.loc[0:2, :]
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
#
#    Start date      Salary
# 0  2008-11-28    $162,700
# 1  2009-10-09  $1,200,000
# 2  2009-01-12     $86,000

# %%
#rows 0-2, 2 columns
employee.loc[0:2, ['Name', 'Position']]
# Out:
#              Name                       Position
# 0      Airi Satou                     Accountant
# 1  Angelica Ramos  Chief Executive Officer (CEO)
# 2      Ashton Cox        Junior Technical Author

# %%
#rows 0-2, columns 0-3
employee.loc[0:2, 'Name':'Office']
# Out:
#              Name                       Position         Office
# 0      Airi Satou                     Accountant          Tokyo
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London
# 2      Ashton Cox        Junior Technical Author  San Francisco

# %%
#rows with certain condition
employee.loc[employee.Position == 'Accountant', :]
# Out:
#                Name    Position Office  Age  Start date    Salary
# 0        Airi Satou  Accountant  Tokyo   33  2008/11/28  $162,700
# 17  Garrett Winters  Accountant  Tokyo   63  2011/07/25  $170,750

# %%
#chapter 7 - dropna
#employee = pd.read_table('D:/Udemy/resources/Tab_separated_values_missingvalues.tsv')
employee = pd.read_table('Tab_separated_values_missingvalues.tsv')
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary
# 0  2008-11-28    $162,700
# 1  2009-10-09  $1,200,000
# 2  2009-01-12     $86,000
# 3  2012-10-13    $132,000
# 4  2011-06-07    $206,850

# %%
employee.shape
# Out:
# (57, 6)

# %%
#drop rows with all missing values in every column
employee.dropna(how='any').shape
# Out:
# (57, 6)

# %%
#drop rows with all missing values in certain colums
employee.dropna(subset=['Name','Salary'], how='any').shape
# Out:
# (57, 6)

# %%
#chapter 8 - working with plots
#data = pd.read_csv('D:/Udemy/resources/monthly-milk-production-pounds-p.csv')
data = pd.read_csv('monthly-milk-production-pounds-p.csv')
data.shape
#datayı buradan aldım
#https://github.com/plotly/datasets/blob/master/monthly-milk-production-pounds.csv
# Out:
# (168, 2)

# %%
data.head()
# Out:
#      Month  Monthly milk production (pounds per cow)
# 0  1962-01                                       589
# 1  1962-02                                       561
# 2  1962-03                                       640
# 3  1962-04                                       656
# 4  1962-05                                       727

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
#chapter - concept of joins 
#inner
dataframe1 = pd.DataFrame({
    "employee": ["ABC","XYZ","MNO"],
    "age": ["22","25","30"]
})

dataframe1
# Out:
#   employee age
# 0      ABC  22
# 1      XYZ  25
# 2      MNO  30

# %%
dataframe2 = pd.DataFrame({
    "employee": ["ABC","XYZ","PQR"],
    "salary": ["10000","125000","30000"]
})

dataframe2
# Out:
#   employee  salary
# 0      ABC   10000
# 1      XYZ  125000
# 2      PQR   30000

# %%
dataframe3 = pd.merge(dataframe1,dataframe2, on="employee")
dataframe3
# Out:
#   employee age  salary
# 0      ABC  22   10000
# 1      XYZ  25  125000

# %%
#outer
dataframe3 = pd.merge(dataframe1,dataframe2, on="employee", how="outer")
dataframe3
# Out:
#   employee  age  salary
# 0      ABC   22   10000
# 1      XYZ   25  125000
# 2      MNO   30     NaN
# 3      PQR  NaN   30000

# %%
#left
dataframe3 = pd.merge(dataframe1,dataframe2, on="employee", how="left")
dataframe3
# Out:
#   employee age  salary
# 0      ABC  22   10000
# 1      XYZ  25  125000
# 2      MNO  30     NaN

# %%
#right
dataframe3 = pd.merge(dataframe1,dataframe2, on="employee", how="right")
dataframe3
# Out:
#   employee  age  salary
# 0      ABC   22   10000
# 1      XYZ   25  125000
# 2      PQR  NaN   30000

# %%
#chapter 9 - Pivoting 
#excelde ayarladı işleme almadım
#webtraffic = pd.read_csv('D:/Udemy/resources/Pivot.csv')
#webtraffic

# %%
#pivot the data
#webtraffic.pivot(index="Page_Name", columns="Date")

# %%
#pivot tables
#webtraffic.pivot_table(index="Page_Name", aggfunc="sum")

# %%
#webtraffic.pivot_table(index="Page_Name", aggfunc="mean")

# %%
#webtraffic.pivot_table(index="Page_Name", aggfunc="count")

# %%
#chapter 9 - shifting and lagging
#fb_finance = pd.read_csv('D:/Udemy/resources/FB.csv')
#FB dosyası files altında vardı
fb_finance = pd.read_csv('FB.csv')
fb_finance.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-06-27  199.179993  200.750000  195.800003  195.839996  195.839996
# 1  2018-06-28  195.179993  197.339996  193.259995  196.229996  196.229996
# 2  2018-06-29  197.320007  197.600006  193.960007  194.320007  194.320007
# 3  2018-07-02  193.369995  197.449997  192.220001  197.360001  197.360001
# 4  2018-07-03  194.550003  195.399994  192.520004  192.729996  192.729996
#
#      Volume
# 0  18734400
# 1  18172400
# 2  15811600
# 3  13961600
# 4  13489500

# %%
fb_finance.shift(1).head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1  2018-06-27  199.179993  200.750000  195.800003  195.839996  195.839996
# 2  2018-06-28  195.179993  197.339996  193.259995  196.229996  196.229996
# 3  2018-06-29  197.320007  197.600006  193.960007  194.320007  194.320007
# 4  2018-07-02  193.369995  197.449997  192.220001  197.360001  197.360001
#
#        Volume
# 0         NaN
# 1  18734400.0
# 2  18172400.0
# 3  15811600.0
# 4  13961600.0

# %%
#fb_finance = pd.read_csv('D:/Udemy/resources/FB.csv', index_col='Date')
fb_finance = pd.read_csv('FB.csv', index_col='Date')
fb_finance.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-06-27  199.179993  200.750000  195.800003  195.839996  195.839996
# 2018-06-28  195.179993  197.339996  193.259995  196.229996  196.229996
# 2018-06-29  197.320007  197.600006  193.960007  194.320007  194.320007
# 2018-07-02  193.369995  197.449997  192.220001  197.360001  197.360001
# 2018-07-03  194.550003  195.399994  192.520004  192.729996  192.729996
#
#               Volume
# Date
# 2018-06-27  18734400
# 2018-06-28  18172400
# 2018-06-29  15811600
# 2018-07-02  13961600
# 2018-07-03  13489500

# %%
fb_finance.shift(1).head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-06-27         NaN         NaN         NaN         NaN         NaN
# 2018-06-28  199.179993  200.750000  195.800003  195.839996  195.839996
# 2018-06-29  195.179993  197.339996  193.259995  196.229996  196.229996
# 2018-07-02  197.320007  197.600006  193.960007  194.320007  194.320007
# 2018-07-03  193.369995  197.449997  192.220001  197.360001  197.360001
#
#                 Volume
# Date
# 2018-06-27         NaN
# 2018-06-28  18734400.0
# 2018-06-29  18172400.0
# 2018-07-02  15811600.0
# 2018-07-03  13961600.0

# %%
fb_finance.shift(-1).head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-06-27  195.179993  197.339996  193.259995  196.229996  196.229996
# 2018-06-28  197.320007  197.600006  193.960007  194.320007  194.320007
# 2018-06-29  193.369995  197.449997  192.220001  197.360001  197.360001
# 2018-07-02  194.550003  195.399994  192.520004  192.729996  192.729996
# 2018-07-03  194.740005  198.649994  194.029999  198.449997  198.449997
#
#                 Volume
# Date
# 2018-06-27  18172400.0
# 2018-06-28  15811600.0
# 2018-06-29  13961600.0
# 2018-07-02  13489500.0
# 2018-07-03  19684200.0

# %%
#calculate the stock price delta
fb_finance['previous_closing_price'] = fb_finance['Close'].shift(1)
fb_finance.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-06-27  199.179993  200.750000  195.800003  195.839996  195.839996
# 2018-06-28  195.179993  197.339996  193.259995  196.229996  196.229996
# 2018-06-29  197.320007  197.600006  193.960007  194.320007  194.320007
# 2018-07-02  193.369995  197.449997  192.220001  197.360001  197.360001
# 2018-07-03  194.550003  195.399994  192.520004  192.729996  192.729996
#
#               Volume  previous_closing_price
# Date
# 2018-06-27  18734400                     NaN
# 2018-06-28  18172400              195.839996
# 2018-06-29  15811600              196.229996
# 2018-07-02  13961600              194.320007
# 2018-07-03  13489500              197.360001

# %%
fb_finance['closing_price_delta'] = fb_finance['Close'] - fb_finance['previous_closing_price']
fb_finance.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-06-27  199.179993  200.750000  195.800003  195.839996  195.839996
# 2018-06-28  195.179993  197.339996  193.259995  196.229996  196.229996
# 2018-06-29  197.320007  197.600006  193.960007  194.320007  194.320007
# 2018-07-02  193.369995  197.449997  192.220001  197.360001  197.360001
# 2018-07-03  194.550003  195.399994  192.520004  192.729996  192.729996
#
#               Volume  previous_closing_price  closing_price_delta
# Date
# 2018-06-27  18734400                     NaN                  NaN
# 2018-06-28  18172400              195.839996             0.390000
# 2018-06-29  15811600              196.229996            -1.909989
# 2018-07-02  13961600              194.320007             3.039994
# 2018-07-03  13489500              197.360001            -4.630005

# %%
#weekly returns
fb_finance['Weekly Returns'] = ((fb_finance['Close'] - fb_finance['Close'].shift(7))/fb_finance['Close'])*100
fb_finance
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-06-27  199.179993  200.750000  195.800003  195.839996  195.839996
# 2018-06-28  195.179993  197.339996  193.259995  196.229996  196.229996
# 2018-06-29  197.320007  197.600006  193.960007  194.320007  194.320007
# 2018-07-02  193.369995  197.449997  192.220001  197.360001  197.360001
# 2018-07-03  194.550003  195.399994  192.520004  192.729996  192.729996
# 2018-07-05  194.740005  198.649994  194.029999  198.449997  198.449997
# 2018-07-06  198.449997  203.639999  197.699997  203.229996  203.229996
# 2018-07-09  204.929993  205.800003  202.119995  204.740005  204.740005
# 2018-07-10  204.500000  204.910004  202.259995  203.539993  203.539993
# 2018-07-11  202.220001  204.500000  201.750000  202.539993  202.539993
# 2018-07-12  203.429993  207.080002  203.190002  206.919998  206.919998
# 2018-07-13  207.809998  208.429993  206.449997  207.320007  207.320007
# ...

# %%
#write your data to csv
#fb_finance.to_csv('D:/Udemy/resources/FB_write.csv')
fb_finance.to_csv('FB_write.csv')

# %%
#fb_finance.to_csv('D:/Udemy/resources/FB_write_somecolumns.csv', columns=['Volume', 'Weekly Returns'])
fb_finance.to_csv('FB_write_somecolumns.csv', columns=['Volume', 'Weekly Returns'])
