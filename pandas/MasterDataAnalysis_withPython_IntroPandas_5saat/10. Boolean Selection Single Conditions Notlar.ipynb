# %% [markdown]
# # Boolean Selection Single Conditions
#
# ## Boolean Selection
# Boolean Selection, also referred to as **Boolean Indexing**, is the process of selecting subsets of rows from DataFrames (or Series) based on the actual data values and NOT by their labels or integer locations. All of the previous subset selections where done using either labels or integer location and nothing to do with the actual values.
#
# ### Examples of Boolean Selection
#
# Let's see some examples of actual questions (in plain English) that boolean selection can help us answer from the bikes dataset. The term **query** is used to refer to these sorts of questions.
#
# * Find all rides by males
# * Find all rides with duration longer than 2 hours
# * Find all rides that took place between March and June of 2015.
# * Find all the rides with a duration longer than 2 hours by females with temperature higher than 90 degrees
#
# ### All queries have a logical condition
# Each of the above queries have a strict logical condition that must be checked one row at a time.
#
# ### Keep or discard an entire row of data
# If you were to manually answer the above queries, you would need to scan each row and determine whether the row, as a whole, meets the condition. If so, then it is kept in the result, otherwise it is discarded.
#
# ### Each row will have a True or False value associated with it
# When you perform boolean selection, each row of the DataFrame (or value of a Series) will have a `True` or `False` value associated with it that corresponds to the outcome of the logical condition.
#
# ### Begin with a small DataFrame
# We will perform our first boolean selection on our sample DataFrame. Let's read it in now.

# %%
import pandas as pd
df = pd.read_csv('../veriler/sample_data.csv', index_col=0)
df
# Out:
#           state  color    food  age  height  score
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %% [markdown]
# ## Manual filtering the data
# Let's find all the people who are younger than 30 years old. We will do this manually by inspecting the data.
#
# ### Create a list of booleans
# By inspecting the data, we see that `Niko`, `Aaron`, and `Penelope` are all under 30 years old. To signify which people are under 30, we create a list of 7 boolean values corresponding to the 7 rows in the DataFrame. The values in the list that correspond with the positions of `Niko`, `Aaron`, and `Penelope` are `True`. All other values are `False`. `Niko`, `Aaron`, and `Penelope` are the 2nd, 3rd, and 4th rows, so these are the locations in the list that are `True`.

# %%
filt = [False, True, True, True, False, False, False]

# %% [markdown]
# ### Variable name `filt`
# The variable name `filt`, which is just an abbreviation for filter, will be used throughout the book to refer to the sequence of booleans. You are free to use any variable name you like for the sequence of booleans, but being consistent makes your code easier to understand.
#
# ### Pass this list into just the brackets
# The above list has `True` in the 2nd, 3rd, and 4th positions. These will be the rows that are kept in the result during boolean selection. Place the list inside the brackets to complete the selection.

# %%
df[filt]

# %% [markdown]
# ### Wait a second… Isn’t `[ ]` just for column selection?
#
# The primary purpose of *just the brackets* for a DataFrame is to select one or more columns by using either a string or a list of strings. All of a sudden, this example shows entire rows being selected with boolean values. This is what makes pandas, unfortunately, a confusing library to learn and use.
#
# ## Operator Overloading
# *Just the brackets* is **overloaded**. Depending on the inputs, pandas will do something completely different. Here are the rules for the different objects passed to *just the brackets*.
#
# * **string** — return a column as a Series
# * **list of strings** — return all those columns as a DataFrame
# * **sequence of booleans** — select all rows where `True`
# * **slice** — select rows (can do both label and integer location — confusing!) I never do this as it is ambiguous. This will be covered in the **Miscellaneous Subset Selection** chapter.
#
# In summary, *just the brackets* primarily selects columns, but if you pass it a sequence of booleans it will select all rows that are `True`.
#
# ### Using booleans in a Series and not a list
# Instead of a list, we can use a Series of booleans, which will make the same selection. Below, we use the Series constructor to create a Series object. The Series must have the same index as the DataFrame it is selecting from in order to work properly, so we create it with the same index as the original DataFrame. This automatic alignment of the index is important and covered in the **Joining Data** part.

# %%
filt = pd.Series([False, True, True, True, False, False, False], 
                 index=df.index)
filt

# %% [markdown]
# ### Use the boolean Series to do the boolean selection
# Placing the Series directly in the brackets will again select only the rows that correspond with the `True` values in the Series.

# %%
df[filt]

# %% [markdown]
# ## Practical Boolean Selection
# We will almost never create boolean lists/Series manually like we did above but instead use the actual data to create them.
#
# ### Creating boolean Series from column data
# By far the most common way to create a boolean Series will be from the values of one particular column. We will test a condition using one of the six comparison operators:
#
# * `<`
# * `<=`
# * `>`
# * `>=`
# * `==`
# * `!=`
#
#
# Let's begin by reading in the bikes dataset.

# %%
bikes = pd.read_csv('../veriler/bikes.csv')
bikes.head(3)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St      41.90096
# 1       -87.641170              31.0     Wells St & Walton St      41.89993
# 2       -87.653497              15.0  Dearborn St & Monroe St      41.88132
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
# 2     -87.629521            23.0         73.0        10.0        16.1
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy
# 2        -9999.0  mostlycloudy

# %% [markdown]
# ### Create a boolean Series
# Let's create a boolean Series by determining which rows have a trip duration greater than 1000 seconds. To make the comparison, we select the `tripduration` column as a Series and compare it against the integer 1000.

# %%
filt = bikes['tripduration'] > 1000
filt.head(3)
# Out:
# 0    False
# 1    False
# 2     True
# Name: tripduration, dtype: bool

# %% [markdown]
# When we write `bikes['tripduration'] > 1000`, pandas compares each value in the `tripduration` column against 1000. It returns a new Series the same length as `tripduartion` with boolean values corresponding to the outcome of the comparison. Let's verify that the `filt` Series is the same length as the DataFrame.

# %%
len(filt)
# Out:
# 50089

# %%
len(bikes)
# Out:
# 50089

# %% [markdown]
# ### Manually verify correctness
# Take a look at the `tripduration` column to manually verify that only the third row satisfied the condition.
#
# ### Complete the boolean selection
# We can now pass the `filt` boolean Series into *just the brackets* to filter the entire DataFrame to return all the rows in the bikes dataset that have a trip duration greater than 1000. Verify that all `tripduration` values are greater than 1000.

# %%
bikes[filt].head(3)
# Out:
#     trip_id    usertype gender            starttime             stoptime  \
# 2     10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 8     21028  Subscriber   Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 10    24383  Subscriber   Male  2013-07-04 17:17:00  2013-07-04 17:42:00
#
#     tripduration             from_station_name  latitude_start  \
# 2           1040  Sheffield Ave & Kingsbury St       41.909592
# 8           1300  Clinton St & Washington Blvd       41.883380
# 10          1523           Morgan St & 18th St       41.858086
#
#     longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 2        -87.653497              15.0  Dearborn St & Monroe St     41.881320
# 8        -87.641170              31.0    Wood St & Division St     41.903320
# 10       -87.651073              15.0   Damen Ave & Pierce Ave     41.909396
#
#     longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 2      -87.629521            23.0         73.0        10.0        16.1
# 8      -87.672730            15.0         71.1         8.0         0.0
# 10     -87.677692            19.0         79.0        10.0         9.2
#
#     precipitation        events
# 2         -9999.0  mostlycloudy
# 8         -9999.0        cloudy
# 10        -9999.0  mostlycloudy

# %% [markdown]
# ### How many rows have a trip duration greater than 1000?
# To answer this question, let's assign the result of the boolean selection to a variable and then compare the number of rows between it and the original DataFrame.

# %%
bikes_duration_1000 = bikes[filt]

# %% [markdown]
# Let's find the number of rows in each DataFrame.

# %%
len(bikes)
# Out:
# 50089

# %%
len(bikes_duration_1000)
# Out:
# 10178

# %% [markdown]
# We compute that 20% of the rides are longer than 1,000 seconds.

# %%
len(bikes_duration_1000) / len(bikes)
# Out:
# 0.20319830701351593

# %% [markdown]
# ## Boolean selection in one line
# Often, you will see boolean selection completed in a single line of code instead of the two lines we used above. The expression for the filter is placed directly inside the brackets. Although this method will save a line of code, I recommend assigning the filter as a separate variable to help with readability.

# %%
bikes[bikes['tripduration'] > 1000].head(3)
# Out:
#     trip_id    usertype gender            starttime             stoptime  \
# 2     10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 8     21028  Subscriber   Male  2013-07-03 15:21:00  2013-07-03 15:42:00
# 10    24383  Subscriber   Male  2013-07-04 17:17:00  2013-07-04 17:42:00
#
#     tripduration             from_station_name  latitude_start  \
# 2           1040  Sheffield Ave & Kingsbury St       41.909592
# 8           1300  Clinton St & Washington Blvd       41.883380
# 10          1523           Morgan St & 18th St       41.858086
#
#     longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 2        -87.653497              15.0  Dearborn St & Monroe St     41.881320
# 8        -87.641170              31.0    Wood St & Division St     41.903320
# 10       -87.651073              15.0   Damen Ave & Pierce Ave     41.909396
#
#     longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 2      -87.629521            23.0         73.0        10.0        16.1
# 8      -87.672730            15.0         71.1         8.0         0.0
# 10     -87.677692            19.0         79.0        10.0         9.2
#
#     precipitation        events
# 2         -9999.0  mostlycloudy
# 8         -9999.0        cloudy
# 10        -9999.0  mostlycloudy

# %% [markdown]
# ## Single condition expression
# Our first example tested a single condition (whether the trip duration was 1,000 or more). Let's test a different single condition and find all the rides that happened when the weather was cloudy. We use the `==` operator to test for equality and again pass this variable to the brackets which completes our selection.

# %%
filt = bikes['events'] == 'cloudy'
bikes[filt].head(3)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 6    18880  Subscriber   Male  2013-07-02 17:47:00  2013-07-02 17:56:00
# 7    19689  Subscriber   Male  2013-07-03 09:07:00  2013-07-03 09:16:00
# 8    21028  Subscriber   Male  2013-07-03 15:21:00  2013-07-03 15:42:00
#
#    tripduration             from_station_name  latitude_start  \
# 6           565        Clark St & Randolph St       41.884576
# 7           505       State St & Van Buren St       41.877181
# 8          1300  Clinton St & Washington Blvd       41.883380
#
#    longitude_start  dpcapacity_start                  to_station_name  \
# 6       -87.631890              31.0  Ravenswood Ave & Irving Park Rd
# 7       -87.627844              27.0       Franklin St & Jackson Blvd
# 8       -87.641170              31.0            Wood St & Division St
#
#    latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 6     41.954690     -87.673930            19.0         66.0        10.0
# 7     41.877708     -87.635321            27.0         64.0         7.0
# 8     41.903320     -87.672730            15.0         71.1         8.0
#
#    wind_speed  precipitation  events
# 6        15.0        -9999.0  cloudy
# 7         5.8        -9999.0  cloudy
# 8         0.0        -9999.0  cloudy

# %% [markdown]
# ## Exercises
#
# ### Exercise 1
# <span  style="color:green; font-size:16px">Read in the movie dataset and set the index to be the title. Select all movies that have Tom Hanks as `actor1`. How many of these movies has he starred in?</span>

# %%
movie = pd.read_csv('../veriler/movie.csv', index_col='title')
movie.head()
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Spectre                                     2015.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
#
#                                             duration      director_name  \
# title
# Avatar                                         178.0      James Cameron
# Pirates of the Caribbean: At World's End       169.0     Gore Verbinski
# Spectre                                        148.0         Sam Mendes
# The Dark Knight Rises                          164.0  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens       NaN        Doug Walker
#
#                                             director_fb           actor1  \
# title
# Avatar                                              0.0      CCH Pounder
# Pirates of the Caribbean: At World's End          563.0      Johnny Depp
# Spectre                                             0.0  Christoph Waltz
# The Dark Knight Rises                           22000.0        Tom Hardy
# Star Wars: Episode VII - The Force Awakens        131.0      Doug Walker
#
#                                             actor1_fb            actor2  \
# title
# Avatar                                         1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End      40000.0     Orlando Bloom
# Spectre                                       11000.0      Rory Kinnear
# The Dark Knight Rises                         27000.0    Christian Bale
# Star Wars: Episode VII - The Force Awakens      131.0        Rob Walker
#
#                                             actor2_fb  ... actor3_fb  \
# title                                                  ...
# Avatar                                          936.0  ...     855.0
# Pirates of the Caribbean: At World's End       5000.0  ...    1000.0
# Spectre                                         393.0  ...     161.0
# The Dark Knight Rises                         23000.0  ...   23000.0
# Star Wars: Episode VII - The Force Awakens       12.0  ...       NaN
#
#                                                   gross  \
# title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                            num_reviews  num_voted_users  \
# title
# Avatar                                           723.0           886204
# Pirates of the Caribbean: At World's End         302.0           471220
# Spectre                                          602.0           275868
# The Dark Knight Rises                            813.0          1144337
# Star Wars: Episode VII - The Force Awakens         NaN                8
#
#                                                                                 plot_keywords  \
# title
# Avatar                                                 avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End    goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                   bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises                       deception|imprisonment|lawlessness|police offi...
# Star Wars: Episode VII - The Force Awakens                                                NaN
#
#                                            language country       budget  \
# title
# Avatar                                      English     USA  237000000.0
# Pirates of the Caribbean: At World's End    English     USA  300000000.0
# Spectre                                     English      UK  245000000.0
# The Dark Knight Rises                       English     USA  250000000.0
# Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
#
#                                             imdb_score
# title
# Avatar                                             7.9
# Pirates of the Caribbean: At World's End           7.1
# Spectre                                            6.8
# The Dark Knight Rises                              8.5
# Star Wars: Episode VII - The Force Awakens         7.1
#
# [5 rows x 21 columns]

# %%
filt=movie['actor1']=='Tom Hanks'
movie[filt]
# Out:
#                                      year            color content_rating  \
# title
# Toy Story 3                        2010.0            Color              G
# The Polar Express                  2004.0            Color              G
# Angels & Demons                    2009.0            Color          PG-13
# The Da Vinci Code                  2006.0            Color          PG-13
# Cloud Atlas                        2012.0            Color              R
# Toy Story 2                        1999.0            Color              G
# Cast Away                          2000.0            Color          PG-13
# Road to Perdition                  2002.0            Color              R
# The Terminal                       2004.0            Color          PG-13
# Saving Private Ryan                1998.0            Color              R
# Apollo 13                          1995.0            Color             PG
# You've Got Mail                    1998.0            Color             PG
# The Green Mile                     1999.0            Color              R
# Forrest Gump                       1994.0  Black and White          PG-13
# Captain Phillips                   2013.0            Color          PG-13
# A League of Their Own              1992.0  Black and White             PG
# Bridge of Spies                    2015.0            Color          PG-13
# Extremely Loud & Incredibly Close  2011.0            Color          PG-13
# Saving Mr. Banks                   2013.0            Color          PG-13
# Toy Story                          1995.0            Color              G
# Larry Crowne                       2011.0            Color          PG-13
# Big                                1988.0            Color             PG
# Splash                             1984.0            Color             PG
# That Thing You Do!                 1996.0            Color             PG
#
#                                    duration     director_name  director_fb  \
# title
# Toy Story 3                           103.0       Lee Unkrich        125.0
# The Polar Express                     100.0   Robert Zemeckis          0.0
# Angels & Demons                       146.0        Ron Howard       2000.0
# The Da Vinci Code                     174.0        Ron Howard       2000.0
# Cloud Atlas                           172.0        Tom Tykwer        670.0
# Toy Story 2                            82.0     John Lasseter        487.0
# Cast Away                             143.0   Robert Zemeckis          0.0
# Road to Perdition                     117.0        Sam Mendes          0.0
# The Terminal                          128.0  Steven Spielberg      14000.0
# Saving Private Ryan                   169.0  Steven Spielberg      14000.0
# Apollo 13                             140.0        Ron Howard       2000.0
# You've Got Mail                       119.0       Nora Ephron          0.0
# The Green Mile                        189.0    Frank Darabont          0.0
# Forrest Gump                          142.0   Robert Zemeckis          0.0
# Captain Phillips                      134.0   Paul Greengrass        521.0
# A League of Their Own                 128.0    Penny Marshall        545.0
# Bridge of Spies                       142.0  Steven Spielberg      14000.0
# Extremely Loud & Incredibly Close     129.0    Stephen Daldry        335.0
# Saving Mr. Banks                      125.0  John Lee Hancock        102.0
# Toy Story                              74.0     John Lasseter        487.0
# Larry Crowne                           98.0         Tom Hanks      15000.0
# Big                                   130.0    Penny Marshall        545.0
# Splash                                111.0        Ron Howard       2000.0
# That Thing You Do!                    149.0         Tom Hanks      15000.0
#
#                                       actor1  actor1_fb                actor2  \
# title
# Toy Story 3                        Tom Hanks    15000.0     John Ratzenberger
# The Polar Express                  Tom Hanks    15000.0          Eddie Deezen
# Angels & Demons                    Tom Hanks    15000.0          Ayelet Zurer
# The Da Vinci Code                  Tom Hanks    15000.0            Seth Gabel
# Cloud Atlas                        Tom Hanks    15000.0          Jim Sturgess
# Toy Story 2                        Tom Hanks    15000.0     John Ratzenberger
# Cast Away                          Tom Hanks    15000.0          Paul Sanchez
# Road to Perdition                  Tom Hanks    15000.0  Jennifer Jason Leigh
# The Terminal                       Tom Hanks    15000.0           Chi McBride
# Saving Private Ryan                Tom Hanks    15000.0            Vin Diesel
# Apollo 13                          Tom Hanks    15000.0           Miko Hughes
# You've Got Mail                    Tom Hanks    15000.0        Jean Stapleton
# The Green Mile                     Tom Hanks    15000.0        Jeffrey DeMunn
# Forrest Gump                       Tom Hanks    15000.0  Siobhan Fallon Hogan
# Captain Phillips                   Tom Hanks    15000.0          Chris Mulkey
# A League of Their Own              Tom Hanks    15000.0            Lori Petty
# Bridge of Spies                    Tom Hanks    15000.0          Mark Rylance
# Extremely Loud & Incredibly Close  Tom Hanks    15000.0           Thomas Horn
# Saving Mr. Banks                   Tom Hanks    15000.0           Ruth Wilson
# Toy Story                          Tom Hanks    15000.0     John Ratzenberger
# Larry Crowne                       Tom Hanks    15000.0            Rob Riggle
# Big                                Tom Hanks    15000.0            Jon Lovitz
# Splash                             Tom Hanks    15000.0         Howard Morris
# That Thing You Do!                 Tom Hanks    15000.0       Charlize Theron
#
#                                    actor2_fb  ... actor3_fb        gross  \
# title                                         ...
# Toy Story 3                           1000.0  ...     721.0  414984497.0
# The Polar Express                      726.0  ...     267.0     665426.0
# Angels & Demons                        745.0  ...     294.0  133375846.0
# The Da Vinci Code                      574.0  ...     362.0  217536138.0
# Cloud Atlas                           5000.0  ...    1000.0   27098580.0
# Toy Story 2                           1000.0  ...     967.0  245823397.0
# Cast Away                              410.0  ...     272.0  233630478.0
# Road to Perdition                     1000.0  ...     818.0  104054514.0
# The Terminal                           466.0  ...     232.0   77032279.0
# Saving Private Ryan                  14000.0  ...   13000.0  216119491.0
# Apollo 13                              968.0  ...     552.0  172071312.0
# You've Got Mail                        793.0  ...     744.0  115731542.0
# The Green Mile                         745.0  ...     693.0  136801374.0
# Forrest Gump                           294.0  ...     194.0  329691196.0
# Captain Phillips                       535.0  ...     186.0  107100855.0
# A League of Their Own                  923.0  ...     251.0  107458785.0
# Bridge of Spies                        535.0  ...     423.0   72306065.0
# Extremely Loud & Incredibly Close      467.0  ...      64.0   31836745.0
# Saving Mr. Banks                      2000.0  ...     825.0   83299761.0
# Toy Story                             1000.0  ...     802.0  191796233.0
# Larry Crowne                           839.0  ...     392.0   35565975.0
# Big                                  11000.0  ...     697.0  114968774.0
# Splash                                 161.0  ...      51.0   69800000.0
# That Thing You Do!                    9000.0  ...     982.0   25809813.0
#
#                                                                       genres  \
# title
# Toy Story 3                        Adventure|Animation|Comedy|Family|Fantasy
# The Polar Express                         Adventure|Animation|Family|Fantasy
# Angels & Demons                                             Mystery|Thriller
# The Da Vinci Code                                           Mystery|Thriller
# Cloud Atlas                                                     Drama|Sci-Fi
# Toy Story 2                        Adventure|Animation|Comedy|Family|Fantasy
# Cast Away                                            Adventure|Drama|Romance
# Road to Perdition                                       Crime|Drama|Thriller
# The Terminal                                                    Comedy|Drama
# Saving Private Ryan                                         Action|Drama|War
# Apollo 13                                            Adventure|Drama|History
# You've Got Mail                                         Comedy|Drama|Romance
# The Green Mile                                   Crime|Drama|Fantasy|Mystery
# Forrest Gump                                                    Comedy|Drama
# Captain Phillips                                    Biography|Drama|Thriller
# A League of Their Own                                     Comedy|Drama|Sport
# Bridge of Spies                                       Drama|History|Thriller
# Extremely Loud & Incredibly Close                    Adventure|Drama|Mystery
# Saving Mr. Banks                        Biography|Comedy|Drama|History|Music
# Toy Story                          Adventure|Animation|Comedy|Family|Fantasy
# Larry Crowne                                            Comedy|Drama|Romance
# Big                                      Comedy|Drama|Family|Fantasy|Romance
# Splash                                                Comedy|Fantasy|Romance
# That Thing You Do!                                        Comedy|Drama|Music
#
#                                   num_reviews  num_voted_users  \
# title
# Toy Story 3                             453.0           544884
# The Polar Express                       188.0           120798
# Angels & Demons                         298.0           207839
# The Da Vinci Code                       294.0           314253
# Cloud Atlas                             511.0           284825
# Toy Story 2                             191.0           385871
# Cast Away                               221.0           394317
# Road to Perdition                       226.0           200359
# The Terminal                            151.0           303864
# Saving Private Ryan                     219.0           881236
# Apollo 13                               159.0           208817
# You've Got Mail                         153.0           151812
# The Green Mile                          186.0           782610
# Forrest Gump                            149.0          1251222
# Captain Phillips                        491.0           323353
# A League of Their Own                    41.0            71754
# Bridge of Spies                         459.0           178118
# Extremely Loud & Incredibly Close       283.0            81298
# Saving Mr. Banks                        405.0           117719
# Toy Story                               166.0           623757
# Larry Crowne                            218.0            49205
# Big                                      99.0           153468
# Splash                                   43.0            54723
# That Thing You Do!                       75.0            50311
#
#                                                                        plot_keywords  \
# title
# Toy Story 3                                   college|day care|escape|teddy bear|toy
# The Polar Express                       boy|christmas|christmas eve|north pole|train
# Angels & Demons                    conclave|illuminati|murder|reference to bernin...
# The Da Vinci Code                  based on supposedly true story|holy grail|mary...
# Cloud Atlas                        composer|future|letter|nonlinear timeline|nurs...
# Toy Story 2                                          collector|dog|friend|rescue|toy
# Cast Away                          christmas|island|love|survival|talking to inan...
# Road to Perdition                                 1930s|blood|gun|on the run|revenge
# The Terminal                       airport|construction site|fish out of water|fl...
# Saving Private Ryan                  army|invasion|killed in action|normandy|soldier
# Apollo 13                          cape kennedy|news footage|reference to christo...
# You've Got Mail                    bookstore|competing businesses|instant messagi...
# The Green Mile                     1930s|death row inmate|healing|prison guard|so...
# Forrest Gump                               amputee|love|vietnam|vietnam war|war hero
# Captain Phillips                               hijacking|hostage|leader|ship|somalia
# A League of Their Own                        baseball|friend|oregon|rivalry|softball
# Bridge of Spies                                  cia|cold war|lawyer|negotiation|spy
# Extremely Loud & Incredibly Close                fear|mourning|mute|quest|revelation
# Saving Mr. Banks                   author|disney|loss of father|reference to walt...
# Toy Story                                     claw crane|cowboy|jealousy|rivalry|toy
# Larry Crowne                       bus stop|college|community college|scooter|spe...
# Big                                                friend|job|new york city|toy|wish
# Splash                             cmnf|cmnf scene|mermaid|new york city|public n...
# That Thing You Do!                               band|drummer|jazz|pennsylvania|song
#
#                                   language  country       budget  imdb_score
# title
# Toy Story 3                        English      USA  200000000.0         8.3
# The Polar Express                  English      USA  165000000.0         6.6
# Angels & Demons                    English      USA  150000000.0         6.7
# The Da Vinci Code                  English      USA  125000000.0         6.6
# Cloud Atlas                        English  Germany  102000000.0         7.5
# Toy Story 2                        English      USA   90000000.0         7.9
# Cast Away                          English      USA   90000000.0         7.7
# Road to Perdition                  English      USA   80000000.0         7.7
# The Terminal                       English      USA   60000000.0         7.3
# Saving Private Ryan                English      USA   70000000.0         8.6
# Apollo 13                          English      USA   62000000.0         7.6
# You've Got Mail                    English      USA   65000000.0         6.5
# The Green Mile                     English      USA   60000000.0         8.5
# Forrest Gump                       English      USA   55000000.0         8.8
# Captain Phillips                   English      USA   55000000.0         7.9
# A League of Their Own              English      USA   40000000.0         7.2
# Bridge of Spies                    English      USA   40000000.0         7.6
# Extremely Loud & Incredibly Close  English      USA   40000000.0         6.9
# Saving Mr. Banks                   English      USA   35000000.0         7.5
# Toy Story                          English      USA   30000000.0         8.3
# Larry Crowne                       English      USA   30000000.0         6.1
# Big                                English      USA   18000000.0         7.3
# Splash                             English      USA    8000000.0         6.2
# That Thing You Do!                 English      USA   26000000.0         6.9
#
# [24 rows x 21 columns]

# %% [markdown]
# ### Exercise 2
# <span  style="color:green; font-size:16px">Select movies with an IMDB score greater than 9.</span>

# %%
#movie[movie['imdb_score']>9] #boyle yaptım
filt=movie['imdb_score']>9
movie[filt]
# Out:
#                             year  color content_rating  duration  \
# title
# The Shawshank Redemption  1994.0  Color              R     142.0
# Towering Inferno             NaN  Color            NaN      65.0
# Dekalog                      NaN  Color          TV-MA      55.0
# The Godfather             1972.0  Color              R     175.0
# Kickboxer: Vengeance      2016.0    NaN            NaN      90.0
#
#                                  director_name  director_fb          actor1  \
# title
# The Shawshank Redemption        Frank Darabont          0.0  Morgan Freeman
# Towering Inferno                John Blanchard          0.0    Martin Short
# Dekalog                                    NaN          NaN  Krystyna Janda
# The Godfather             Francis Ford Coppola          0.0       Al Pacino
# Kickboxer: Vengeance            John Stockwell        134.0    Matthew Ziff
#
#                           actor1_fb           actor2  actor2_fb  ...  \
# title                                                            ...
# The Shawshank Redemption    11000.0   Jeffrey DeMunn      745.0  ...
# Towering Inferno              770.0    Andrea Martin      179.0  ...
# Dekalog                        20.0  Olaf Lubaszenko        3.0  ...
# The Godfather               14000.0    Marlon Brando    10000.0  ...
# Kickboxer: Vengeance       260000.0       T.J. Storm      454.0  ...
#
#                          actor3_fb        gross       genres num_reviews  \
# title
# The Shawshank Redemption     461.0   28341469.0  Crime|Drama       199.0
# Towering Inferno             176.0          NaN       Comedy         NaN
# Dekalog                        2.0     447093.0        Drama        53.0
# The Godfather               3000.0  134821952.0  Crime|Drama       208.0
# Kickboxer: Vengeance         354.0          NaN       Action         2.0
#
#                           num_voted_users  \
# title
# The Shawshank Redemption          1689764
# Towering Inferno                       10
# Dekalog                             12590
# The Godfather                     1155770
# Kickboxer: Vengeance                  246
#
#                                                               plot_keywords  \
# title
# The Shawshank Redemption  escape from prison|first person narration|pris...
# Towering Inferno                                                        NaN
# Dekalog                   meaning of life|moral challenge|morality|searc...
# The Godfather             crime family|mafia|organized crime|patriarch|r...
# Kickboxer: Vengeance                                                    NaN
#
#                          language country      budget  imdb_score
# title
# The Shawshank Redemption  English     USA  25000000.0         9.3
# Towering Inferno          English  Canada         NaN         9.5
# Dekalog                    Polish  Poland         NaN         9.1
# The Godfather             English     USA   6000000.0         9.2
# Kickboxer: Vengeance          NaN     USA  17000000.0         9.1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Exercise 3
# <span  style="color:green; font-size:16px">Write a function that accepts a single parameter to find the number of movies for a given content rating. Use the function to find the number of movies for ratings 'R', 'PG-13', and 'PG'.</span>
