# %%
"""
https://www.udemy.com/course/pandas-for-anybody/learn/lecture/28121624?start=0#overview
1,5 saat
Kelvin Fosu eğitimi
https://pandas.pydata.org/docs/user_guide/10min.html#min

atom, pycharm, anaconda kurdu

https://pandas.pydata.org/

covid dataset
https://covid19.who.int/table

anaconda prompttan pip list dersek python yüklü paketlerini görebiliriz
https://pypi.org/search/?q=text+to+speech
pypi dan da bakabiliriz 


https://covid19.who.int/data
https://covid19.who.int/WHO-COVID-19-global-data.csv
https://covid19.who.int/WHO-COVID-19-global-table-data.csv
https://covid19.who.int/who-data/vaccination-data.csv
https://covid19.who.int/who-data/vaccination-metadata.csv

"""

# %%
import numpy as np
import pandas as pd

# %%
#conda install -c anaconda pandas-profiling
#sonra y/n çıkarsa y ile devam ederiz
#anaconda prompt yönetici olarak çalıştırılırsa daha iyi olabilir
#etkisi olmadı ancak denenebilir

# %%
y=pd.Series([1,2,3])
y
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
k=pd.Series([1,2,3],index=["me","you","us"])
k
# Out:
# me     1
# you    2
# us     3
# dtype: int64

# %%
k['me']
# Out:
# 1

# %%
y[2]
# Out:
# 3

# %%
#DataFrame

# %%
#df csv, dictionary ve jsondan oluşturulabilir

# %%
m=pd.DataFrame({'Name':['Kelvin','Rose','Enoch'],'food':['rice','waakye','beans'],'age':[10,20,30]})
m
# Out:
#      Name    food  age
# 0  Kelvin    rice   10
# 1    Rose  waakye   20
# 2   Enoch   beans   30

# %%
m.shape
# Out:
# (3, 3)

# %%
m.values
# Out:
# array([['Kelvin', 'rice', 10],
#        ['Rose', 'waakye', 20],
#        ['Enoch', 'beans', 30]], dtype=object)

# %%
m.columns
# Out:
# Index(['Name', 'food', 'age'], dtype='object')

# %%
m.dtypes
# Out:
# Name    object
# food    object
# age      int64
# dtype: object

# %%
#WHO-COVID-19-global-data.csv  bu data üzerinden gidiyor

# %%
#!pip install pandas-profiling

# %%
#import sys
#!{sys.executable} -m pip install pandas-profiling

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
import pandas_profiling as pp
#from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-586d7e88b112> in <module>
# ----> 1 import pandas_profiling as pp
#       2 #from pandas_profiling import ProfileReport
#
# ~\Anaconda3\lib\site-packages\pandas_profiling\__init__.py in <module>
#       5
#       6 from pandas_profiling.config import Config, config
# ----> 7 from pandas_profiling.controller import pandas_decorator
#       8 from pandas_profiling.profile_report import ProfileReport
#       9 from pandas_profiling.version import __version__
#
# ~\Anaconda3\lib\site-packages\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.__init__ import ProfileReport
#       5
#       6
#
# ~\Anaconda3\lib\site-packages\pandas_profiling\__init__.py in <module>
#       6 from pandas_profiling.config import Config, config
# ...

# %%
dfcovid=pd.read_csv('WHO-COVID-19-global-data.csv')

# %%
dfcovid
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 227041    2022-08-13           ZW     Zimbabwe       AFRO          0
# 227042    2022-08-14           ZW     Zimbabwe       AFRO         17
# 227043    2022-08-15           ZW     Zimbabwe       AFRO          0
# 227044    2022-08-16           ZW     Zimbabwe       AFRO         22
# 227045    2022-08-17           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
pp.ProfileReport(dfcovid)
#pandas downgrade etmek ya da beklemek gerekiyor uyumlu çalışsın diye
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2956e5b08bbc> in <module>
# ----> 1 pp.ProfileReport(dfcovid)
#
# NameError: name 'pp' is not defined

# %%
dfcovid.index
# Out:
# RangeIndex(start=0, stop=227046, step=1)

# %%
dfcovid.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
dfcovid.values
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2022-08-15', 'ZW', 'Zimbabwe', ..., 256539, 0, 5588],
#        ['2022-08-16', 'ZW', 'Zimbabwe', ..., 256561, 0, 5588],
#        ['2022-08-17', 'ZW', 'Zimbabwe', ..., 256561, 0, 5588]],
#       dtype=object)

# %%
dfcovid.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
dfcovid.shape
# Out:
# (227046, 8)

# %%
dfcovid.head(10)
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
# 5    2020-01-08           AF  Afghanistan       EMRO          0
# 6    2020-01-09           AF  Afghanistan       EMRO          0
# 7    2020-01-10           AF  Afghanistan       EMRO          0
# 8    2020-01-11           AF  Afghanistan       EMRO          0
# 9    2020-01-12           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# ...

# %%
dfcovid.tail(10)
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 227036    2022-08-08           ZW  Zimbabwe       AFRO         10
# 227037    2022-08-09           ZW  Zimbabwe       AFRO          3
# 227038    2022-08-10           ZW  Zimbabwe       AFRO          2
# 227039    2022-08-11           ZW  Zimbabwe       AFRO         21
# 227040    2022-08-12           ZW  Zimbabwe       AFRO          9
# 227041    2022-08-13           ZW  Zimbabwe       AFRO          0
# 227042    2022-08-14           ZW  Zimbabwe       AFRO         17
# 227043    2022-08-15           ZW  Zimbabwe       AFRO          0
# 227044    2022-08-16           ZW  Zimbabwe       AFRO         22
# 227045    2022-08-17           ZW  Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 227036            256487           0               5584
# 227037            256490           2               5586
# 227038            256492           1               5587
# ...

# %%
dfcovid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227046 entries, 0 to 227045
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      227046 non-null  object
#  1   Country_code       226088 non-null  object
#  2   Country            227046 non-null  object
#  3   WHO_region         227046 non-null  object
#  4   New_cases          227046 non-null  int64
#  5   Cumulative_cases   227046 non-null  int64
#  6   New_deaths         227046 non-null  int64
#  7   Cumulative_deaths  227046 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 13.9+ MB

# %%
dfcovid.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  2.270460e+05      2.270460e+05  227046.000000       2.270460e+05
# mean   2.597185e+03      8.148192e+05      28.348965       1.347064e+04
# std    1.652384e+04      4.085712e+06     154.983620       6.091542e+04
# min   -3.295200e+04      0.000000e+00   -2440.000000       0.000000e+00
# 25%    0.000000e+00      4.410000e+02       0.000000       4.000000e+00
# 50%    2.200000e+01      1.572600e+04       0.000000       1.900000e+02
# 75%    4.910000e+02      2.236452e+05       5.000000       3.417000e+03
# max    1.255831e+06      9.184634e+07   11447.000000       1.027094e+06

# %%
dfcovid.Country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
dfcovid.WHO_region.unique()
# Out:
# array(['EMRO', 'EURO', 'AFRO', 'WPRO', 'AMRO', 'SEARO', 'Other'],
#       dtype=object)

# %%
#Kolonlarıdaki boşlukları silelim
dfcovid.columns = [col.strip() for col in dfcovid.columns]
dfcovid.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
dfcovid.min()
# Out:
# C:\Users\Bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Date_reported         2020-01-03
# Country              Afghanistan
# WHO_region                  AFRO
# New_cases                 -32952
# Cumulative_cases               0
# New_deaths                 -2440
# Cumulative_deaths              0
# dtype: object

# %%
dfcovid.max()
# Out:
# C:\Users\Bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Date_reported                                               2022-08-17
# Country              occupied Palestinian territory, including east...
# WHO_region                                                        WPRO
# New_cases                                                      1255831
# Cumulative_cases                                              91846336
# New_deaths                                                       11447
# Cumulative_deaths                                              1027094
# dtype: object

# %%
dfcovid.mean()
#uzun sürüyor
# Out:
# C:\Users\Bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# New_cases              2597.184571
# Cumulative_cases     814819.152361
# New_deaths               28.348965
# Cumulative_deaths     13470.637082
# dtype: float64

# %%
dfcovid.std()
# Out:
# C:\Users\Bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# New_cases            1.652384e+04
# Cumulative_cases     4.085712e+06
# New_deaths           1.549836e+02
# Cumulative_deaths    6.091542e+04
# dtype: float64

# %%
dfcovid.count()
# Out:
# Date_reported        227046
# Country_code         226088
# Country              227046
# WHO_region           227046
# New_cases            227046
# Cumulative_cases     227046
# New_deaths           227046
# Cumulative_deaths    227046
# dtype: int64

# %%
dfcovid.Country=='United States of America'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 227041    False
# 227042    False
# 227043    False
# 227044    False
# 227045    False
# Name: Country, Length: 227046, dtype: bool

# %%
dfcovid[dfcovid.Country=='United States of America']
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 216508    2020-01-03           US  United States of America       AMRO
# 216509    2020-01-04           US  United States of America       AMRO
# 216510    2020-01-05           US  United States of America       AMRO
# 216511    2020-01-06           US  United States of America       AMRO
# 216512    2020-01-07           US  United States of America       AMRO
# ...              ...          ...                       ...        ...
# 217461    2022-08-13           US  United States of America       AMRO
# 217462    2022-08-14           US  United States of America       AMRO
# 217463    2022-08-15           US  United States of America       AMRO
# 217464    2022-08-16           US  United States of America       AMRO
# 217465    2022-08-17           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
#kolonları rename etmek istersek dictionary üzerinden gidebiliriz
#dfcovid = dfcovid.rename(columns={"Deaths - cumulative total":"Total Deaths","Cases - cumulative total per 100000 population":"Cases cum Per Thousand Pop"})

# %%
dfcovid.reset_index()
# Out:
#          index Date_reported Country_code      Country WHO_region  New_cases  \
# 0            0    2020-01-03           AF  Afghanistan       EMRO          0
# 1            1    2020-01-04           AF  Afghanistan       EMRO          0
# 2            2    2020-01-05           AF  Afghanistan       EMRO          0
# 3            3    2020-01-06           AF  Afghanistan       EMRO          0
# 4            4    2020-01-07           AF  Afghanistan       EMRO          0
# ...        ...           ...          ...          ...        ...        ...
# 227041  227041    2022-08-13           ZW     Zimbabwe       AFRO          0
# 227042  227042    2022-08-14           ZW     Zimbabwe       AFRO         17
# 227043  227043    2022-08-15           ZW     Zimbabwe       AFRO          0
# 227044  227044    2022-08-16           ZW     Zimbabwe       AFRO         22
# 227045  227045    2022-08-17           ZW     Zimbabwe       AFRO          0
#
# ...

# %%
dfcovid.reset_index().head(41)
# Out:
#     index Date_reported Country_code      Country WHO_region  New_cases  \
# 0       0    2020-01-03           AF  Afghanistan       EMRO          0
# 1       1    2020-01-04           AF  Afghanistan       EMRO          0
# 2       2    2020-01-05           AF  Afghanistan       EMRO          0
# 3       3    2020-01-06           AF  Afghanistan       EMRO          0
# 4       4    2020-01-07           AF  Afghanistan       EMRO          0
# 5       5    2020-01-08           AF  Afghanistan       EMRO          0
# 6       6    2020-01-09           AF  Afghanistan       EMRO          0
# 7       7    2020-01-10           AF  Afghanistan       EMRO          0
# 8       8    2020-01-11           AF  Afghanistan       EMRO          0
# 9       9    2020-01-12           AF  Afghanistan       EMRO          0
# 10     10    2020-01-13           AF  Afghanistan       EMRO          0
# 11     11    2020-01-14           AF  Afghanistan       EMRO          0
# ...

# %%
dfcovid.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
#Yeni kolon ekleme
#dfcovid['Testing_cases'] = (dfcovid["Cases - newly reported in last 7 days"]/dfcovid["Total deaths"])*100
#dfcovid
#egitimdeki dataya göre yazıldı şimdi elimizdeki dataya göre yapalım

# %%
dfcovid['Testing_cases'] = (dfcovid["New_cases"]/dfcovid["Cumulative_deaths"])*100
dfcovid
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 227041    2022-08-13           ZW     Zimbabwe       AFRO          0
# 227042    2022-08-14           ZW     Zimbabwe       AFRO         17
# 227043    2022-08-15           ZW     Zimbabwe       AFRO          0
# 227044    2022-08-16           ZW     Zimbabwe       AFRO         22
# 227045    2022-08-17           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  Testing_cases
# ...

# %%
#df['sum_covidset'] = (df['testing_case']+ df['new_cases'])
#df

# %%
#df = df.drop(['sum_covidset'],axis=1) ile kolonu silebiliriz

# %%
dfcovid.isnull()
# Out:
#         Date_reported  Country_code  Country  WHO_region  New_cases  \
# 0               False         False    False       False      False
# 1               False         False    False       False      False
# 2               False         False    False       False      False
# 3               False         False    False       False      False
# 4               False         False    False       False      False
# ...               ...           ...      ...         ...        ...
# 227041          False         False    False       False      False
# 227042          False         False    False       False      False
# 227043          False         False    False       False      False
# 227044          False         False    False       False      False
# 227045          False         False    False       False      False
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  Testing_cases
# 0                  False       False              False           True
# ...

# %%
print(dfcovid.isnull())
# Out:
#         Date_reported  Country_code  Country  WHO_region  New_cases  \
# 0               False         False    False       False      False
# 1               False         False    False       False      False
# 2               False         False    False       False      False
# 3               False         False    False       False      False
# 4               False         False    False       False      False
# ...               ...           ...      ...         ...        ...
# 227041          False         False    False       False      False
# 227042          False         False    False       False      False
# 227043          False         False    False       False      False
# 227044          False         False    False       False      False
# 227045          False         False    False       False      False
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  Testing_cases
# 0                  False       False              False           True
# ...

# %%
print(dfcovid.isnull().sum())
# Out:
# Date_reported            0
# Country_code           958
# Country                  0
# WHO_region               0
# New_cases                0
# Cumulative_cases         0
# New_deaths               0
# Cumulative_deaths        0
# Testing_cases        41252
# dtype: int64

# %%
#https://medium.com/wicds/a-comprehensive-guide-to-pandas-for-data-science-64ed1be1bafe
#https://medium.com/swlh/the-mastery-of-pandas-i-50156db42125

# %%
#titanic dataset
#https://www.kaggle.com/code/gokultalele/titanic-machine-learning-from-disaster/data
#3 adet dosya indirildi  gender_submission, train test.csv

# %%
#https://exercism.org/
