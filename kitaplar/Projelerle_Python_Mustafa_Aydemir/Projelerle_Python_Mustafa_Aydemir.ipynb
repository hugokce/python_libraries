# %%
print("Merhaba Projeler!")
# Out:
# Merhaba Projeler!

# %%
sayi = input("Bir sayi girin: ")
# Out:
# Bir sayi girin: 1

# %%
type(sayi)
# Out:
# str

# %%
int_sayi = int(sayi)

# %%
type(int_sayi)
# Out:
# int

# %%
türkçe_bir_değişken = "Türkçe'yi severiz."

# %%
print(türkçe_bir_değişken)
# Out:
# Türkçe'yi severiz.

# %%
def türkçe_fonksiyon():
    print("Merhaba Türkçe")

# %%
türkçe_fonksiyon()
# Out:
# Merhaba Türkçe

# %%
a = range(1,10)
a
# Out:
# range(1, 10)

# %%
b = list(a)
b
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
9//5
# Out:
# 1

# %%
9.0/5
# Out:
# 1.8

# %%
9/5
# Out:
# 1.8

# %%
8/4
# Out:
# 2.0

# %%
isim = input("Adınız: ")
soyisim = input("Soyadınız: ")
print("Merhaba "+isim + ' '+ soyisim +' Nasılsınız')
# Out:
# Adınız: Aslan
# Soyadınız: Kesen
# Merhaba Aslan Kesen Nasılsınız

# %% [markdown]
# Internet sitelerine bağlanmak

# %%
import urllib.request

# %%
site_adresi = "http://hurriyet.com.tr"

# %%
html = urllib.request.urlopen(site_adresi)

# %%
print(html.read())
# Out:
# b'<!DOCTYPE html><html lang="tr"><head><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><title>H&#252;rriyet - Haber, Son Dakika Haberler, G&#252;ncel Gazete Haberleri</title><link rel="icon" type="image/png" href="/favicon-logo.png" /><meta property="fb:page_id" content="233408450693" /><meta property="fb:app_id" content="117890861638620" /><style>[class*=" icon-"], [class*=font-icon-], [class^=icon-], [class^=font-icon-] {speak: none;font-style: normal;font-variant: normal;text-transform: none;-webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;font-weight: 400}.h16-main-header .search-box-wrapper .search-box-text-input:focus, :focus, button {outline: 0}button, input[type=text] {padding: 0}.cf:after, .container:after, .news-wrapper.narrow-box:after, .row:after {clear: both}[class*=" icon-"], [class^=icon-] {font-family: icomoon !important;line-height: 1}.icon-cropy:before {content: "\\e918"}.icon-arrow2:before {content: "\\e907"}.icon-ar
# ...

# %%
import urllib.request as ur

# %%
kullanici_site_adresi = input("Hangi siteye gitmek istersiniz?: ")
# Out:
# Hangi siteye gitmek istersiniz?: http://hurriyet.com.tr

# %%
html = ur.urlopen(kullanici_site_adresi)

# %%
print("\nİstediğiniz sitenin kaynak kodu: \n\n")
# Out:
# İstediğiniz sitenin kaynak kodu:

# %%
print(html.read())
# Out:
# b'<!DOCTYPE html><html lang="tr"><head><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><title>H&#252;rriyet - Haber, Son Dakika Haberler, G&#252;ncel Gazete Haberleri</title><link rel="icon" type="image/png" href="/favicon-logo.png" /><meta property="fb:page_id" content="233408450693" /><meta property="fb:app_id" content="117890861638620" /><style>[class*=" icon-"], [class*=font-icon-], [class^=icon-], [class^=font-icon-] {speak: none;font-style: normal;font-variant: normal;text-transform: none;-webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;font-weight: 400}.h16-main-header .search-box-wrapper .search-box-text-input:focus, :focus, button {outline: 0}button, input[type=text] {padding: 0}.cf:after, .container:after, .news-wrapper.narrow-box:after, .row:after {clear: both}[class*=" icon-"], [class^=icon-] {font-family: icomoon !important;line-height: 1}.icon-cropy:before {content: "\\e918"}.icon-arrow2:before {content: "\\e907"}.icon-ar
# ...

# %%
header_kodlarim = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.116 Safari/537.36'
}

# %%
istek = ur.Request(kullanici_site_adresi,headers=header_kodlarim)

# %%
html = ur.urlopen(istek)

# %%
print(html.read())
# Out:
# b'<!DOCTYPE html><html lang="tr"><head><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><title>H&#252;rriyet - Haber, Son Dakika Haberler, G&#252;ncel Gazete Haberleri</title><link rel="icon" type="image/png" href="/favicon-logo.png" /><meta property="fb:page_id" content="233408450693" /><meta property="fb:app_id" content="117890861638620" /><style>[class*=" icon-"], [class*=font-icon-], [class^=icon-], [class^=font-icon-] {speak: none;font-style: normal;font-variant: normal;text-transform: none;-webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;font-weight: 400}.h16-main-header .search-box-wrapper .search-box-text-input:focus, :focus, button {outline: 0}button, input[type=text] {padding: 0}.cf:after, .container:after, .news-wrapper.narrow-box:after, .row:after {clear: both}[class*=" icon-"], [class^=icon-] {font-family: icomoon !important;line-height: 1}.icon-cropy:before {content: "\\e918"}.icon-arrow2:before {content: "\\e907"}.icon-ar
# ...

# %%
kullanici_adi = 'mustafa'
sifre = 123456
email = 'mustafa@aydemir.im'
isim = 'Mustafa Aydemir'

# %%
#kullanici_adi='mustafa'&sifre=123456&email='mustafa@aydemir.im'&isim='Mustafa Aydemir'
# Out:
#   File "<ipython-input-45-4d8a92f9bdd0>", line 1
#     kullanici_adi='mustafa'&sifre=123456&email='mustafa@aydemir.im'&isim='Mustafa Aydemir'
#                  ^
# SyntaxError: can't assign to operator

# %%
veriler = {
    "kullanici_adi" : "mustafa",
    "sifre" : "123456",
    "email" : "mustafa@aydemir.im",
    "isim" : "Mustafa Aydemir"    
}

# %%
import urllib.parse

# %%
satir = urllib.parse.urlencode(veriler)

# %%
print(satir)
# Out:
# kullanici_adi=mustafa&sifre=123456&email=mustafa%40aydemir.im&isim=Mustafa+Aydemir

# %%
import urllib.request
import urllib.parse

site_adresi="http://hurriyet.com.tr"

header_kodlarim = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.116 Safari/537.36'
}

veriler = {
    "kullanici_adi" : "mustafa",
    "sifre" : "123456",
    "email" : "mustafa@aydemir.im",
    "isim" : "Mustafa Aydemir"    
}

parametreler = urllib.parse.urlencode(veriler)

tam_site_adresi = site_adresi+"?"+parametreler

istek = urllib.request.Request(tam_site_adresi,headers=header_kodlarim)

html = urllib.request.urlopen(istek)

print(html.read())
# Out:
# b'<!DOCTYPE html><html lang="tr"><head><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><title>H&#252;rriyet - Haber, Son Dakika Haberler, G&#252;ncel Gazete Haberleri</title><link rel="icon" type="image/png" href="/favicon-logo.png" /><meta property="fb:page_id" content="233408450693" /><meta property="fb:app_id" content="117890861638620" /><style>[class*=" icon-"], [class*=font-icon-], [class^=icon-], [class^=font-icon-] {speak: none;font-style: normal;font-variant: normal;text-transform: none;-webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;font-weight: 400}.h16-main-header .search-box-wrapper .search-box-text-input:focus, :focus, button {outline: 0}button, input[type=text] {padding: 0}.cf:after, .container:after, .news-wrapper.narrow-box:after, .row:after {clear: both}[class*=" icon-"], [class^=icon-] {font-family: icomoon !important;line-height: 1}.icon-cropy:before {content: "\\e918"}.icon-arrow2:before {content: "\\e907"}.icon-ar
# ...

# %% [markdown]
# POST METHOD

# %%
import urllib.request
import urllib.parse

site_adresi="http://hurriyet.com.tr"

header_kodlarim = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.116 Safari/537.36'
}

veriler = {
    "kullanici_adi" : "mustafa",
    "sifre" : "123456",
    "email" : "mustafa@aydemir.im",
    "isim" : "Mustafa Aydemir"    
}

parametreler = urllib.parse.urlencode(veriler)
parametreler = parametreler.encode('utf-8')

istek = urllib.request.Request(tam_site_adresi,data=parametreler,headers=header_kodlarim)

html = urllib.request.urlopen(istek)

print(html.read())
# Out:
# b'<!DOCTYPE html><html lang="tr"><head><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><title>H&#252;rriyet - Haber, Son Dakika Haberler, G&#252;ncel Gazete Haberleri</title><link rel="icon" type="image/png" href="/favicon-logo.png" /><meta property="fb:page_id" content="233408450693" /><meta property="fb:app_id" content="117890861638620" /><style>[class*=" icon-"], [class*=font-icon-], [class^=icon-], [class^=font-icon-] {speak: none;font-style: normal;font-variant: normal;text-transform: none;-webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;font-weight: 400}.h16-main-header .search-box-wrapper .search-box-text-input:focus, :focus, button {outline: 0}button, input[type=text] {padding: 0}.cf:after, .container:after, .news-wrapper.narrow-box:after, .row:after {clear: both}[class*=" icon-"], [class^=icon-] {font-family: icomoon !important;line-height: 1}.icon-cropy:before {content: "\\e918"}.icon-arrow2:before {content: "\\e907"}.icon-ar
# ...

# %%
import urllib.request
urllib.request.urlretrieve("http://www.google.com/favicon.ico","indirilen_dosya.ico")
# Out:
# ('indirilen_dosya.ico', <http.client.HTTPMessage at 0x252a657fb08>)

# %%
urllib.request.urlretrieve("http://google.com/favicon.ico","/Users/indirilen_dosya.ico")
# Out:
# ('/Users/Bootcamp/Desktop/indirilen_dosya.ico',
#  <http.client.HTTPMessage at 0x252a6588e48>)

# %%
import urllib.request
import re

try:
    
    site_adresi = input("Site adresini lütfen http:// ile giriniz: ")
    print("\n")
    html = urllib.request.urlopen(site_adresi)
    html = html.read()
    html = str(html)
    
    tanim = "<title>(.*?)</title>"
    ara = re.search(tanim,html)
    
    if ara:
        etiket = ara.group(0)
        icerik = ara.group(1)
        
        print("Etiket: "+etiket)
        print("İçerik: "+icerik)
        
    else:
        print("İstediğiniz etiket kaynak kodların içinde yer almamaktadır.")

except:        
    print("Beklenmeyen bir hata oluştu")
# Out:
# Site adresini lütfen http:// ile giriniz: http://hurriyet.com.tr
#
#
# Etiket: <title>H&#252;rriyet - Haber, Son Dakika Haberler, G&#252;ncel Gazete Haberleri</title>
# İçerik: H&#252;rriyet - Haber, Son Dakika Haberler, G&#252;ncel Gazete Haberleri

# %%
#API ile karekod oluşturma

# %%
#https://api.qrserver.com/v1/create-qr-code/?size=150*150&data=Mustafa+Aydemir

# %%
size = input("Resim boyutu: ")
veri = input("İçerik: ")
# Out:
# Resim boyutu: 150*150
# İçerik: test

# %%
import urllib.parse

size = input("Resim boyutu: ")

veri = input("İçerik: ") 

veriler = {
    'size':size+'*'+size,
    'data':veri
    
}

parametreler = urllib.parse.urlencode(veriler)

api_link = "https://api.qrserver.com/v1/create-qr-code/?size=150*150&data=Mustafa+Aydemir"+parametreler
# Out:
# Resim boyutu: 150
# İçerik: mustafa

# %%
import urllib.parse
import urllib.request

try:
    
    print("\n")
    size = input("Resim boyutu: ")

    veri = input("İçerik: ")
    
    veriler = {
    'size':size+'*'+size,
    'data':veri
    }
    
    parametreler = urllib.parse.urlencode(veriler)
    
    api_link = "https://api.qrserver.com/v1/create-qr-code/?"+parametreler
    
    urllib.request.urlretrieve(api_link,"kare_kod.png")
    
    print("\n")
    print("Kare kod başarıyla oluşturuldu.")
    print("kare_kod.png isimli dosyadan ulaşabilirsiniz")
    print("\n")
    

except:        
    print("Beklenmeyen bir hata oluştu")
# Out:
# Resim boyutu: 150
# İçerik: mustafa
#
#
# Kare kod başarıyla oluşturuldu.
# kare_kod.png isimli dosyadan ulaşabilirsiniz

# %%
#SMTP

# %%
import smtplib
from email.mime.text import MIMEText

# %%
smtp_adresi="smtp-mail.outlook.com"
smtp_port=587
kullanici_adi="mstfydmr@outlook.com"
sifre="sifre123456."

# %%
gonderilecek_adresler = ["mustafa@aydemir.im","mstfydmr@outlook.com"]
konu = "Mail Konusu (Başlık)"

icerik = """
Python ile gönderilen mailimizin içeriği.
<br><br>
Test içerik.
<br>
<div style="color:#ae0000;font-weight:bold">Önemli yazı.</div>
<div style="font-size:20px">Büyük Yazı</div>
<div style="text-shadow:0 0 10px #ae0000;font-size:20px;font-weight:bold;">Kırmızı Gölgeli Yazı</div>

<br>
--<br>

<strong style="display:inline-block;padding:5px 10px;margin:5px 0;background-color:#fafafa;border:solid 1px #e0e0e0;">
<span style="color:777">Mustafa</span> <span style="color:#d35400">Aydemir</span>
</strong><br>

"""

# %%
mail = MIMEText(icerik,"html","utf-8")

# %%
mail["From"]=kullanici_adi
mail["Subject"]=konu
mail["To"]=",".join(gonderilecek_adresler)

mail = mail.as_string()

print(mail)
# Out:
# Content-Type: text/html; charset="utf-8"
# MIME-Version: 1.0
# Content-Transfer-Encoding: base64
# From: mstfydmr@outlook.com
# Subject: =?utf-8?b?TWFpbCBLb251c3UgKEJhxZ9sxLFrKQ==?=
# To: mustafa@aydemir.im,mstfydmr@outlook.com
#
# ClB5dGhvbiBpbGUgZ8O2bmRlcmlsZW4gbWFpbGltaXppbiBpw6dlcmnEn2kuCjxicj48YnI+ClRl
# c3QgacOnZXJpay4KPGJyPgo8ZGl2IHN0eWxlPSJjb2xvcjojYWUwMDAwO2ZvbnQtd2VpZ2h0OmJv
# bGQiPsOWbmVtbGkgeWF6xLEuPC9kaXY+CjxkaXYgc3R5bGU9ImZvbnQtc2l6ZToyMHB4Ij5Cw7x5
# w7xrIFlhesSxPC9kaXY+CjxkaXYgc3R5bGU9InRleHQtc2hhZG93OjAgMCAxMHB4ICNhZTAwMDA7
# Zm9udC1zaXplOjIwcHg7Zm9udC13ZWlnaHQ6Ym9sZDsiPkvEsXJtxLF6xLEgR8O2bGdlbGkgWWF6
# xLE8L2Rpdj4KCjxicj4KLS08YnI+Cgo8c3Ryb25nIHN0eWxlPSJkaXNwbGF5OmlubGluZS1ibG9j
# aztwYWRkaW5nOjVweCAxMHB4O21hcmdpbjo1cHggMDtiYWNrZ3JvdW5kLWNvbG9yOiNmYWZhZmE7
# Ym9yZGVyOnNvbGlkIDFweCAjZTBlMGUwOyI+CjxzcGFuIHN0eWxlPSJjb2xvcjo3NzciPk11c3Rh
# ZmE8L3NwYW4+IDxzcGFuIHN0eWxlPSJjb2xvcjojZDM1NDAwIj5BeWRlbWlyPC9zcGFuPgo8L3N0
# cm9uZz48YnI+Cgo=

# %%
s =smtplib.SMTP(smtp_adresi,smtp_port)
s.starttls()
# Out:
# (220, b'2.0.0 SMTP server ready')

# %%
#s.login(kullanici_adi,sifre)
#s.sendmail(kullanici_adi,gonderilecek_adresler,mail)

# %%
import smtplib
from email.mime.text import MIMEText

smtp_adresi="smtp-mail.outlook.com"
smtp_port=587
kullanici_adi="mstfydmr@outlook.com"
sifre="sifre123456."

gonderilecek_adresler = ["mustafa@aydemir.im","mstfydmr@outlook.com"]
konu = "Mail Konusu (Başlık)"

icerik = """
Python ile gönderilen mailimizin içeriği.
<br><br>
Test içerik.
<br>
<div style="color:#ae0000;font-weight:bold">Önemli yazı.</div>
<div style="font-size:20px">Büyük Yazı</div>
<div style="text-shadow:0 0 10px #ae0000;font-size:20px;font-weight:bold;">Kırmızı Gölgeli Yazı</div>

<br>
--<br>

<strong style="display:inline-block;padding:5px 10px;margin:5px 0;background-color:#fafafa;border:solid 1px #e0e0e0;">
<span style="color:777">Mustafa</span> <span style="color:#d35400">Aydemir</span>
</strong><br>

"""

try:
    mail = MIMEText(icerik,"html","utf-8")
    
    mail["From"]=kullanici_adi
    mail["Subject"]=konu
    mail["To"]=",".join(gonderilecek_adresler)
    
    mail = mail.as_string()

    print("Lütfen bekleyiniz")
    
    s =smtplib.SMTP(smtp_adresi,smtp_port)
    s.starttls()
    
    #s.login(kullanici_adi,sifre)
    #s.sendmail(kullanici_adi,gonderilecek_adresler,mail)
    print("Mail gönderme işi başarılı")
    
    
except Exception as e:
    print(str(e))
# Out:
# Lütfen bekleyiniz
# Mail gönderme işi başarılı

# %%
#Veritabanı işlemleri

# %%
import sqlite3

# %%
db = sqlite3.connect("veritabanı.db")
#veya db = sqlite3.connect("../veritabani.db")
#veya db = sqlite3.connect("/Users/veritabani.db")

# %%
#gecici db
#db = sqlite3.connect(":memory:")
#disk üzerinde ise
#db = sqlite3.connect("")

# %%
cr = db.cursor()

# %%
cr.execute("CREATE TABLE IF NOT EXISTS uyeler ('isim','soyisim','email','sifre')")

# %%
cr.execute("SELECT name FROM sqlite_master where type='table'")

# %%
tablolar = cr.fetchall()
print(tablolar)
# Out:
# [('uyeler',)]

# %%
cr.execute("INSERT INTO uyeler (isim,soyisim,email,sifre) VALUES ('Mustafa','Aydemir','mustafa@aydemir.im','123456')")

# %%
db.commit()

# %%
import sqlite3

db = sqlite3.connect("veritabanı.db")

cr = db.cursor()

cr.execute("CREATE TABLE IF NOT EXISTS uyeler ('isim','soyisim','email','sifre')")

cr.execute("INSERT INTO uyeler (isim,soyisim,email,sifre) VALUES ('Mustafa','Aydemir','mustafa@aydemir.im','123456')")

db.commit()

cr.execute("SELECT isim,soyisim FROM uyeler WHERE soyisim = 'Aydemir'")

cekilen_veriler=cr.fetchall()

print(cekilen_veriler)
# Out:
# [('Mustafa', 'Aydemir'), ('Mustafa', 'Aydemir'), ('Mustafa', 'Aydemir'), ('Mustafa', 'Aydemir'), ('Mustafa', 'Aydemir')]

# %%
print(cekilen_veriler[0][1])
# Out:
# Aydemir

# %%
for veri in cekilen_veriler:
    print("İsim :"+ veri[0])
    print("Soyisim :"+veri[1])
    print()
# Out:
# İsim :Mustafa
# Soyisim :Aydemir
#
# İsim :Mustafa
# Soyisim :Aydemir
#
# İsim :Mustafa
# Soyisim :Aydemir
#
# İsim :Mustafa
# Soyisim :Aydemir
#
# İsim :Mustafa
# Soyisim :Aydemir

# %%
#Zip işlemleri

# %%
import zipfile

# %%
z = zipfile.ZipFile("C:/Users/testfile_for_zip.zip","r")

# %%
dosyalar = z.namelist()
print()

# %%
for i in dosyalar:
    print(i)
print()
# Out:
# test_for_zip3.txt
# test_for_zip1.txt
# test_for_zip2.txt

# %%
#CGI ile web sitesi yapımı bölümü eklenmedi

# %%
import zipfile

dosya = "C:/Users/testfile_for_zip.zip"

hedef = "C:/Users/dosyalar_cikti"

if zipfile.is_zipfile(dosya):
    with zipfile.ZipFile(dosya,"r") as z:
        z.extractall(hedef)
else:
    print()
    print("Açmaya çalıştığınız dosya ZIP formatında değil.")
    print()

# %%
import zipfile

dosya = "dosyalar2.zip"

z = zipfile.ZipFile(dosya,mode="w",compression=zipfile.ZIP_DEFLATED)

z.writestr("not.txt","Deneme Mesaj")

z.close()

# %%
import zipfile

dosya = "C:/Users/dosyalar2.zip"

z = zipfile.ZipFile(dosya,mode="w",compression=zipfile.ZIP_DEFLATED)

z.write("C:/Users/test_for_zip1.txt",arcname="yeni_isim1.txt")

z.write("C:/Users/test_for_zip2.txt",arcname="yeni_isim2.txt")

z.write("C:/Users/test_for_zip3.txt",arcname="yeni_isim3.txt")

z.close()

# %%
#JSON İşlemleri

# %%
import json

# %%
arabalar = {
    "audi": {
        "A3": {
            "renk_secenekleri":["Siyah","Beyaz","Gri"],
            "yakıt":"Benzin"
             },
        "A7":{
            "renk_secenekleri":["Siyah","Beyaz"],
            "yakıt":"Dizel"
            }  
    },
    "jeep":{
        "CHEROKEE":{
            "renk_secenekleri":["Siyah"],
            "yakıt":"Benzin"
        },
        "WRANGLER":{
            "renk_secenekleri":["Siyah","Beyaz"],
            "yakıt":"Benzin"            
        }
    }  
}

# %%
json_veri=json.dumps(arabalar)

# %%
json_veri
# Out:
# '{"audi": {"A3": {"renk_secenekleri": ["Siyah", "Beyaz", "Gri"], "yak\\u0131t": "Benzin"}, "A7": {"renk_secenekleri": ["Siyah", "Beyaz"], "yak\\u0131t": "Dizel"}}, "jeep": {"CHEROKEE": {"renk_secenekleri": ["Siyah"], "yak\\u0131t": "Benzin"}, "WRANGLER": {"renk_secenekleri": ["Siyah", "Beyaz"], "yak\\u0131t": "Benzin"}}}'

# %%
import json

json_verisi = """{"isim":"Mustafa","soyisim":"Aydemir"}"""

veriler = json.loads(json_verisi)

print(veriler["isim"])
print(veriler["soyisim"])
# Out:
# Mustafa
# Aydemir

# %%
#Tkinter

# %%
from tkinter import *

# %%
pencere = Tk()

# %%
pencere.title("Pencere Başlığı")
mainloop()

# %%
pencere.geometry("500*100")

# %%
pencere.geometry("200*300")

# %%
pencere.geometry("200*200x300+100")

# %%
pencere.resizable(False,False)

# %%
pencere.resizable(True,False)

# %%
pencere.resizable(False,True)

# %%
pencere.minsize(100,100)

# %%
pencere.maxsize(800,800)

# %%
from tkinter import *

pencere = Tk()

pencere.title("Pencere Başlığı")

pencere.geometry("200x200+300+100")

pencere.resizable(False,False)

pencere.minsize(100,100)

pencere.maxsize(800,800)

mainloop()

# %%
#Boyutları ve konumu öğrenme

# %%
from tkinter import *

pencere = Tk()

pencere.title("Pencere Başlığı")

pencere.geometry("200x200+100+100")

print("Pencere Boyutu Hesaplanıyor")

pencere.update()

en=pencere.winfo_width()

boy=pencere.winfo_height()

sol=pencere.winfo_x()

ust=pencere.winfo_y()

pencere_ici_sol = pencere.winfo_rootx()

pencere_ici_ust = pencere.winfo_rooty()

print("En :" + str(en))

print("Boy :" + str(boy))

print("Sol :" + str(sol))

print("Üst :" + str(ust))

print("Pencere İçi Sol :" + str(pencere_ici_sol))

print("Pencere İçi Üst :" + str(pencere_ici_ust))

mainloop()
# Out:
# Pencere Boyutu Hesaplanıyor
# En :200
# Boy :200
# Sol :100
# Üst :100
# Pencere İçi Sol :108
# Pencere İçi Üst :131

# %%
#Pencere Durumu

pencere.state("normal")

pencere.state("zoomed")

pencere.state("iconic")

pencere.state("withdrawn")
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-5-a45a0cf46a9f> in <module>
#       1 #Pencere Durumu
#       2
# ----> 3 pencere.state("normal")
#       4
#       5 pencere.state("zoomed")
#
# ~\Anaconda3\lib\tkinter\__init__.py in wm_state(self, newstate)
#    1979         """Query or set the state of this widget as one of normal, icon,
#    1980         iconic (see wm_iconwindow), withdrawn, or zoomed (Windows only)."""
# -> 1981         return self.tk.call('wm', 'state', self._w, newstate)
#    1982     state = wm_state
#    1983     def wm_title(self, string=None):
#
# TclError: can't invoke "wm" command: application has been destroyed

# %%
pencere.wm_attributes("-alpha",0.5)

# %%
pencere.wm_attributes("-topmost",1)

# %%
pencere.wm_attributes("-fullscreen",1)

# %%
from tkinter import *

pencere = Tk()

print("Genişlik : "+ str(pencere.winfo_screenwidth()))
print("Yükseklik : "+str(pencere.winfo_screenheight()))

mainloop()
# Out:
# Genişlik : 1536
# Yükseklik : 864

# %%
from tkinter import *

pencere = Tk()

print("Sol : "+ str(pencere.winfo_pointerx()))
print("Üst : "+str(pencere.winfo_pointery()))

mainloop()
# Out:
# Sol : 470
# Üst : 161

# %%
from tkinter import *

pencere = Tk()

pencere.title("Pencere Başlığı")

pencere.geometry("200x200+300+100")

pencere.overrideredirect(1)

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Başlık 1")
pencere.geometry("200x200+0+0")

pencere = Tk()
pencere.title("Başlık 2")
pencere.geometry("100x300+400+400")

pencere = Tk()
pencere.title("Başlık 3")
pencere.geometry("300x100+1000+1000")

pencere = Tk()
pencere.title("Başlık 4")
pencere.geometry("500x100+200+800")

pencere = Tk()
pencere.title("Başlık 5")
pencere.geometry("700x700+400+400")
pencere.wm_attributes("-alpha",0.5)

mainloop()

# %%
from tkinter import *

pencere = Tk()

pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

yazi = Label(text="Hello Tkinter")
yazi.pack()

mainloop()

# %%
yazi = Label(
    text = "Hello Tkinter",
    fg = "red"
)

# %%
yazi = Label(
    text = "Hello Tkinter",
    fg = "#ae0000"
)

# %%
yazi = Label(
    text = "Hello Tkinter",
    fg = "#cccccc",
    bg = "#ae0000"
)

# %%
yazi = Label(
    text = "Hello Tkinter",
    fg = "#cccccc",
    bg = "#ae0000",
    
    width = 10,
    height = 10
)

# %%
yazi = Label(
    text = "Hello Tkinter",
    fg = "#cccccc",
    bg = "#ae0000",
    
    padx = 50,
    pady = 30
)

# %%
yazi = Label(
    text = "Hello Tkinter",
    fg = "#cccccc",
    bg = "#ae0000",
    
    padx = 50,
    pady = 30,
    
    font = ("Open Sans","30","bold")
)

# %%
yazi = Label(
    text = "Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter",
    fg = "#cccccc",
    bg = "#ae0000",
    
    padx = 50,
    pady = 30,
    
    wraplength = 100
)

# %%
yazi = Label(
    text = "Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter",
    fg = "#cccccc",
    bg = "#ae0000",
    
    padx = 50,
    pady = 30,
    
    wraplength = 180,
    justify = "left"
)

# %%
yazi = Label(
    text = "Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter",
    fg = "#cccccc",
    bg = "#ae0000",
    
    padx = 50,
    pady = 30,
    
    wraplength = 180,
    justify = "right"
)

# %%
yazi = Label(
    text = "Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter Hello Tkinter",
    fg = "#cccccc",
    bg = "#ae0000",
    
    padx = 50,
    pady = 30,
    
    wraplength = 180,
    justify = "center"
)

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

yazi = Label(
    text = "Python",
    fg = "#cccccc",
    bg = "#ae0000",
    
    width = 50,
    height = 50,
    
    anchor = "ne",
    
)

yazi.pack()

mainloop()

# %%
yazi = Label(
    text = "Python",
    fg = "#cccccc",
    bg = "#ae0000",
    
    width = 50,
    height = 50,
    
    cursor = "cross",
    
)

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

resim = PhotoImage(file="gif.gif")

yazi = Label(image=resim)
yazi.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

resim = PhotoImage(file="gif.gif")

yazi = Label(
    image=resim,
    text = "Test Yazı",
    compound = "left"
)
yazi.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

def mesaj_yaz():
    print("Butona basıldı.")
    
buton = Button(
    text = "Mesaj",
    command = mesaj_yaz

)

buton.pack()

mainloop()
# Out:
# Butona basıldı.

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

def yazi_degistir():
    etiket["text"] = "Merhaba Tkinter"

etiket = Label(text="Hello Tkinter !")
etiket.pack()

buton = Button(
    text = "Mesaj",
    command = yazi_degistir

)

buton.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

def yazi_degistir():
    etiket["text"] = "Merhaba Tkinter"
    
etiket = Label(text="Hello Tkinter !")
etiket.pack()

buton = Button(
    text = "Değiştir",
    command = yazi_degistir,
    state = "disabled"

)

buton.pack()

mainloop()

# %%
buton = Button(
    text = "Değiştir",
    command = yazi_degistir,
    state = "disabled",
    
    disabledforeground ="red",
    activeforeground = "black",
    activebackground = "yellow",

)

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

def yazi_degistir():
    etiket["text"] = "Merhaba Tkinter"
    
etiket = Label(text="Hello Tkinter !")
etiket.pack()

buton = Button(
    text = "Değiştir",
    command = yazi_degistir,

)

buton.pack()
buton.invoke()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

def kapat():
    quit()
    
buton = Button(
    text = "Kapat",
    command = kapat,

)

buton.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

yazi = Entry()
yazi.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

def veri_al():
    etiket["text"] = yazi.get()
    
yazi = Entry()
yazi.pack()

buton = Button(
    text = "Veri Al",
    command = veri_al,

)

buton.pack()

etiket = Label(text = "Yazı buraya yazılacak")
etiket.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")
    
yazi = Entry()
yazi.pack()

yazi.insert(0,"Test yazısı")

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x50+300+100")
    
yazi = Entry()
yazi.pack()

yazi.insert(0,"Test yazısı")
yazi.insert(3,"Mustafa")

mainloop()

# %%
yazi.delete(0,"end")

# %%
yazi.delete("sel.first","sel.last")

# %%
yazi.delete("insert","end")

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x50+300+100")
    
yazi = Entry()
yazi.pack()

yazi.insert(0,"Test yazısı")
yazi.delete(3,5)

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x50+300+100")
    
yazi = Entry(show = "*")
yazi.pack()

yazi.insert(0,"Test yazısı")

mainloop()

# %%
yazi = Entry(takefocus=0)

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x50+300+100")
    
list = Listbox()
list.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x50+300+100")
    
list = Listbox()
list.pack()

list.insert(END,"Python")
list.insert(END,"PHP")
list.insert(END,"C#")
list.insert(END,"Ruby")
list.insert(END,"JavaScript")

mainloop()

# %%
list = Listbox(selectmode = BROWSE)

# %%
list = Listbox(selectmode = SINGLE)

# %%
list = Listbox(selectmode = MULTIPLE)

# %%
list = Listbox(selectmode = EXTENDED)

# %%
list.get(0,END)

# %%
print(list.get(0,END))

# %%
list.delete(ACTIVE)

# %%
list.delete(0,END)

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x50+300+100")

onay = Checkbutton(text = "Onayla")
onay.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x50+300+100")

x = IntVar()

def kontrol():
    
    if x.get() ==0:
        etiket["text"]="Onaylanmamış"
    
    else:
        etiket["text"]="Onaylanmış"
        
x.set(1)

onay = Checkbutton(text = "Onayla",variable=x,command=kontrol)
onay.pack()

etiket = Label()
etiket.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x50+300+100")

x = StringVar()

x.set("Python")

def yazdir():
    
    etiket["text"]=x.get()

python = Radiobutton(text="Python",value="Python",variable=x,command=yazdir)    
python.pack()

php = Radiobutton(text = "PHP",value="PHP",variable=x,command=yazdir)
php.pack()

javascript = Radiobutton(text = "JavaScript",value="JavaScript",variable=x,command=yazdir)
javascript.pack()

etiket = Label()
etiket.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x50+300+100")

yazi = Text()
yazi.pack()

mainloop()

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

yazi = Label(text="Python")
yazi.pack()

mainloop()

# %%
yazi = Label(text="Python")
yazi.pack(side="left")

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.pack(fill="x")

# %%
yazi.pack(expand=1)

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.pack(anchor="ne")

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.pack(anchor="s",expand=1)

# %%
yazi.pack(anchor="nw",padx=10,pady=10)

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.place()

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.place(x=80,y=30)

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.place(x=80,y=0.3)

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.place(width=100,height=200)

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.place(relwidth=0.10,relheight=0.50)

# %%
from tkinter import *

pencere = Tk()
pencere.title("Pencere Başlığı")
pencere.geometry("200x200+300+100")

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid()

mainloop()

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=0,column=0)

# %%
yazi2 = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi2.grid(row=1,column=1)

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=0,column=0)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=1,column=1)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=2,column=0)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=0,column=1)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=3,column=2)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=4,column=3)

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=0,column=0)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=1,column=1)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=2,column=0)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=0,column=1,columnspan=3)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=3,column=2)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=4,column=3)

# %%
yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=0,column=0)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=1,column=1)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=2,column=0)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=0,column=1,columnspan=3,sticky="e")

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=3,column=2)

yazi = Label(text="Python",bg="#ae0000",fg="#cccccc")
yazi.grid(row=4,column=3)

# %%
#kitap sona erdi
